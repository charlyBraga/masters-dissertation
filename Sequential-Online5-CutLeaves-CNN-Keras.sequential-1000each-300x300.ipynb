# %% [markdown]
# #**CNN Keras Sequential for Cut images**

# %% [markdown]
# ##Drive preapare

# %% [markdown]
# #####Common Labraries

# %%
is_local = False

if not is_local:
  from google.colab import drive
  drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import os
import shutil
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, AlphaDropout

print(tf.__version__)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 2.14.0

# %% [markdown]
# #####Create sheet to save data history

# %%
if is_local:
  root_drive ='E:\\Drive\\Poscomp2023\\CutLeaves\\cutleaves-final-augmentation\\original-size\\' #local images original_augmentation_1000each
  split = '\\'
else:
  root_drive = '/content/drive/MyDrive/Poscomp2023/CutLeaves/cutleaves-final-augmentation/original-size/' #remote drive
  split = '/'
dst_path = root_drive + 'history/'

def save_df_history(df_history, optmizer_name,type_model):
  file_name = f'History-Sequential-Keras-CNN-{optmizer_name}.xlsx'
  with pd.ExcelWriter(dst_path + file_name) as writer:
    df_history.to_excel(writer, sheet_name='sheet1')

def print_df_history(df_history):
  print(df_history)

# %% [markdown]
# ##Get images

# %% [markdown]
# #####Separate image

# %%
width = 300
height = 300


my_class_names = ['health', 'miner', 'rust']

def keras_preprocessing_image_dataset_from_directory(root, step, my_shuffle, my_batch_size):
  if os.path.exists(root+step+'.ipynb_checkpoints'):
    shutil.rmtree(root+step+'.ipynb_checkpoints')
  return tf.keras.preprocessing.image_dataset_from_directory(
            directory = root + step,
            labels = 'inferred', #labels criadas baseadas em subpastas
            label_mode = 'categorical', # mias de duas saíds possíves
            batch_size = my_batch_size,
            image_size = (width, height), #redimensiona imagem para valores de width e height
            shuffle = my_shuffle,  #define se imagens serão embaralhadas nos batch
            #class_names = my_class_names,  # Replace class names
            seed=1, #Allow always the same shuffle (default random)
            #interpolation =  =&quot;bilinear&quot;,#  bilinear, nearest, bicubic, area, lanczos3, lanczos5, gaussian, mitchellcubic.
            #crop_to_aspect_ratio = False
          )


def get_batch_size(train):
  train_iterator = train.as_numpy_iterator()
  for image, label in train_iterator:
    return image.shape[0]


print('++ Data about loaded dataset ++')
#Batch_size = 32
print('\nDataset batach_size=32')
train_32 = keras_preprocessing_image_dataset_from_directory(root_drive, f'train{split}', True, 32)
valid_32  = keras_preprocessing_image_dataset_from_directory(root_drive, f'valid{split}', False, 32)
test_32 = keras_preprocessing_image_dataset_from_directory(root_drive, f'test{split}', False, 32)
print(f"Load images batch_size={get_batch_size(train_32)}")

print(f'Classes names: {train_32.class_names}')

#Batch_size = 64
print('\nDataset batach_size=64')
train_64 = keras_preprocessing_image_dataset_from_directory(root_drive, f'train{split}', True, 64)
valid_64  = keras_preprocessing_image_dataset_from_directory(root_drive,  f'valid{split}', False, 64)
test_64 = keras_preprocessing_image_dataset_from_directory(root_drive, f'test{split}', False, 64)
print(f"Load images batch_size={get_batch_size(train_64)}")
print(f'Classes names: {train_64.class_names}')

#Batch_size = 128
print('\nDataset batach_size=128')
train_128 = keras_preprocessing_image_dataset_from_directory(root_drive, f'train{split}', True, 128)
valid_128  = keras_preprocessing_image_dataset_from_directory(root_drive,  f'valid{split}', False, 128)
test_128 = keras_preprocessing_image_dataset_from_directory(root_drive, f'test{split}', False, 128)
print(f"Load images batch_size={get_batch_size(train_128)}")
print(f'Classes names: {train_128.class_names}')
# Out:
# ++ Data about loaded dataset ++
#
# Dataset batach_size=32
# Found 2400 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.
# Load images batch_size=32
# Classes names: ['health', 'miner', 'rust']
#
# Dataset batach_size=64
# Found 2400 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.
# Load images batch_size=64
# Classes names: ['health', 'miner', 'rust']
#
# Dataset batach_size=128
# Found 2400 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.
# Load images batch_size=128
# Classes names: ['health', 'miner', 'rust']

# %% [markdown]
# #####View classes images

# %% [markdown]
# Get images and labels

# %%
def convert_label_to_class_name(label):
  id = np.where(sample_label == 1.0)[0][0]
  current_class_name = my_class_names[id]
  return current_class_name

train_32_iterator = train_32.as_numpy_iterator()
for img, label in train_32_iterator:
    break

class_index = 3
sample_image = img[class_index]
sample_label = label[class_index]
print(f'Image color min-max: ' + '[{:.2f}'.format(sample_image.min()) + '-'+ '{:.2f}'.format(sample_image.max()) + ']')
print(f'Label: {sample_label}')
class_name = convert_label_to_class_name(label)
plt.imshow(sample_image/255.0) #inshow plot image only in format color [0,1]
plt.title(f'Sample Image | class {class_name}')
plt.axis('off')
plt.show()
cv2.destroyAllWindows();
# Out:
# Image color min-max: [0.00-185.17]
# Label: [0. 0. 1.]

# %%
from IPython.core.interactiveshell import validate
#def extract_images_and_labels(images, labels):
#    return images, labels

# Apply the function to each batch of data
#train_dataset = train.map(extract_images_and_labels)
# Iterate over the batches to extract x and y
img_channel = None
print('\nTranning image shape:')
for x, y in train_32:
    print('Batch of images:', x.shape)
    _, _, _, img_channel = x.shape
    print('Batch of labels:', y.shape)
    break

print('\nValidation image shape:')
for x, y in valid_32:
    print('Batch of images:', x.shape)
    print('Batch of labels:', y.shape)
    break

print('\nTesting image shape:')
for x, y in test_32:
    print('Batch of images:', x.shape)
    print('Batch of labels:', y.shape)
    break

print(f'\nImages channel: {img_channel}')

#batch_img_train = 32
#batch_img_train, _ = next(train)
#batch_img_valid, _ = next(valid)
#batch_img_test, _ = next(test)
#print(f"Batch of images shape - train: {batch_img_train.shape}, valid: {batch_img_valid.shape}, test: {batch_img_test.shape} ")
num_classes = len(train_32.class_names)
num_classes
# Out:
# Tranning image shape:
# Batch of images: (32, 300, 300, 3)
# Batch of labels: (32, 3)
#
# Validation image shape:
# Batch of images: (32, 300, 300, 3)
# Batch of labels: (32, 3)
#
# Testing image shape:
# Batch of images: (32, 300, 300, 3)
# Batch of labels: (32, 3)
#
# Images channel: 3
# 3

# %% [markdown]
# ##Model

# %% [markdown]
# #####Create model 1

# %%
#Use ReLU
def layers_config1():
  #model = create_model()
  #model.add(tf.keras.layers.MaxPooling2D((2,2)))
  #model.add(tf.keras.layers.Conv2D(64, (3,3), activation='relu'))
  #model.add(tf.keras.layers.MaxPooling2D((2,2)))
  #model.add(tf.keras.layers.Flatten())
  #model.add(tf.keras.layers.Dense(128, activation='relu'))
  #model.add(tf.keras.layers.Dense(3, activation='softmax'))

  model = tf.keras.Sequential()
  # Assume the input is a 2D image of shape (height, width, channels).
  # Here's a simple convolutional block:
  model.add(tf.keras.layers.Conv2D(32, (3, 3), padding='same', input_shape=(height, width, img_channel)))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.ReLU())
  model.add(tf.keras.layers.MaxPooling2D((2, 2)))

  # Additional convolutional block:
  model.add(tf.keras.layers.Conv2D(64, (3, 3), padding='same'))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.ReLU())
  model.add(tf.keras.layers.MaxPooling2D((2, 2)))

  # Flatten the tensor output to feed it into a dense layer:
  model.add(tf.keras.layers.Flatten())

  # Dense layer:
  model.add(tf.keras.layers.Dense(128))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.ReLU())
  #model.add(tf.keras.layers.LeakyReLU()) #função melhorada de ReLU

  # Output layer:
  model.add(tf.keras.layers.Dense(3, activation='softmax'))

  return model, '1'

#model1_print, layers_config1_print= layers_config1()
#print(f'\n\n ++ Model Layers configuraration {layers_config1_print} ++\n\n')
#model1_print.summary()
#del model1_print, layers_config1_print

# %% [markdown]
# #####Create model 2

# %%
#Change ReLU by LeakyReLU
def layers_config2():
  model = tf.keras.Sequential()
  model.add(tf.keras.layers.Conv2D(32, (3, 3), padding='same', input_shape=(height, width, img_channel)))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.LeakyReLU())
  model.add(tf.keras.layers.MaxPooling2D((2, 2)))

  # Additional convolutional block:
  model.add(tf.keras.layers.Conv2D(64, (3, 3), padding='same'))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.LeakyReLU())
  model.add(tf.keras.layers.MaxPooling2D((2, 2)))

  # Flatten the tensor output to feed it into a dense layer:
  model.add(tf.keras.layers.Flatten())

  # Dense layer:
  model.add(tf.keras.layers.Dense(128))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.LeakyReLU())
  #model.add(tf.keras.layers.LeakyReLU()) #função melhorada de ReLU

  # Output layer:
  model.add(tf.keras.layers.Dense(3, activation='softmax'))

  return model, '2'

#model2_print, layers_config2_print= layers_config2()
#print(f'\n\n ++ Model Layers configuraration {layers_config2_print} ++\n\n')
#model2_print.summary()
#del model2_print, layers_config2_print

# %% [markdown]
# #####Create model 3

# %%
#Add ultimas camdas 64 e 32, e removi 128

def activation_function(model):
    model.add(tf.keras.layers.ReLU())

def model3():
  model = tf.keras.Sequential()
  model.add(tf.keras.layers.Conv2D(32, (3, 3), padding='same', input_shape=(height, width, img_channel)))
  model.add(tf.keras.layers.ReLU())
  model.add(tf.keras.layers.BatchNormalization(synchronized=True))
  model.add(tf.keras.layers.MaxPooling2D((2, 2)))

  # Additional convolutional block:
  model.add(tf.keras.layers.Conv2D(64, (3, 3), padding='same'))#faz convolução entre o filtro (kernel) que é uma parte da imagem
  model.add(tf.keras.layers.ReLU())
  model.add(tf.keras.layers.BatchNormalization(synchronized=True))
  model.add(tf.keras.layers.MaxPooling2D((2, 2))) #pega o maior valor em um quadro 2x2, com duas linhas e duas colunas

  # Flatten the tensor output to feed it into a dense layer:
  model.add(tf.keras.layers.Flatten()) #converte a feature extraída em uma coluna vertical

  # Dense layer:
  model.add(tf.keras.layers.Dense(64)) #camada intermediária com 128 neurônios
  model.add(tf.keras.layers.ReLU())
  model.add(tf.keras.layers.BatchNormalization(synchronized=True))
  #model.add(tf.keras.layers.LeakyReLU()) #função melhorada de ReLU

    # Dense layer:
  model.add(tf.keras.layers.Dense(32)) #camada intermediária com 128 neurônios
  model.add(tf.keras.layers.ReLU())
  model.add(tf.keras.layers.BatchNormalization(synchronized=True))
  #model.add(tf.keras.layers.LeakyReLU()) #função melhorada de ReLU

  # Output layer:
  model.add(tf.keras.layers.Dense(3, activation='softmax')) #camada de saída com 3 neurônios que representam as 3 classes de dados

  return model, '3'

#model3_print, modelid3_print= model3()
#print(f'\n\n ++ Model Layers configuraration {modelid3_print} ++\n\n')
#model3_print.summary()
#del model3_print, modelid3_print

# %% [markdown]
# #####Create model 4

# %%
def model4():
  # Define the model
  model = tf.keras.Sequential()

  # Convolutional blocks (It's uncommon to use SELU here, so we keep ReLU for convolutional layers)
  #my_init =  tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.1, seed=None)
  #model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer=my_init, bias_initializer='zeros', activation='relu', input_shape=(height, width, img_channel)))
  model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(height, width, img_channel)))

  #model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(height, width, img_channel)))
  model.add(MaxPooling2D((2, 2)))

  model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
  model.add(MaxPooling2D((2, 2)))

  # Flatten
  model.add(Flatten())

  # Dense layer
  model.add(Dense(128, activation='selu', kernel_initializer='lecun_normal'))
  model.add(Dense(64, activation='selu', kernel_initializer='lecun_normal'))

  # Additional SELU dense layer
  model.add(Dense(32, activation='selu', kernel_initializer='lecun_normal'))

  # Output layer
  model.add(Dense(num_classes, activation='softmax'))  # Adjust the number of units and the activation function as per your problem

  return model, '4'

# %% [markdown]
# #####Compile Model Sequential

# %%
def compile_model(model, optimizer):
  model.compile(    optimizer=optimizer,
                    loss='categorical_crossentropy', # para mais de duas classes e para penalizar o modelo quando há erro
                    metrics=[ #tf.keras.metrics.Accuracy(),
                              tf.keras.metrics.categorical_accuracy,
                              tf.keras.metrics.AUC(
                                                    num_thresholds = 200,
                                                    curve = 'ROC',
                                                    summation_method = 'interpolation',
                                                    name = None,
                                                    dtype = None,
                                                    thresholds = None,
                                                    multi_label = True,
                                                    num_labels = None,
                                                    label_weights = None,
                                                    from_logits = False
                                                  ),
                              tf.keras.metrics.Precision(thresholds=None, top_k=None, class_id=None, name=None, dtype=None), #Computes the precision of the predictions with respect to the labels.
                              tf.keras.metrics.Recall(thresholds=None, top_k=None, class_id=None, name=None, dtype=None),
                              tf.keras.metrics.TruePositives(thresholds=None, name=None, dtype=None),
                              tf.keras.metrics.TrueNegatives(thresholds=None, name=None, dtype=None),
                              tf.keras.metrics.FalsePositives(thresholds=None, name=None, dtype=None),
                              tf.keras.metrics.FalseNegatives(thresholds=None, name=None, dtype=None)
                            ]
                )
  return model

# %% [markdown]
# ##Train

# %% [markdown]
# #####Show end date

# %%
def calculate_total_time_min(time_start):
  time_end = time()
  time_train_seg = time_end - time_start
  time_train_min = round(time_train_seg/60, 2)
  return  time_train_min

# %% [markdown]
# #####Save History

# %%
import pickle

def save_model(model, path_dst, model_filename):
  model.save(path_dst  + model_filename)


def save_history(history, path_dst, history_filename):
  ##Save history
  with open(path_dst  + history_filename, 'wb') as f:
      pickle.dump(history.history, f)

# %% [markdown]
# #####Show Loss plot

# %%
def show_history_train(history):
  # Plot training & validation loss values
  plt.figure(figsize=(10, 6))
  plt.plot(history.history['loss'], label='Erro de treino')
  plt.plot(history.history['val_loss'], label='Erro de validação')
  plt.title('Erro de treino e validação baseado em iterações')
  plt.xlabel('Iterações')
  plt.ylabel('Erro')
  plt.legend()
  plt.show()

# %% [markdown]
# #####Run train

# %%
from matplotlib import pyplot as plt
from time import time
from tensorflow.keras.callbacks import LearningRateScheduler, LambdaCallback


initial_learning_rate = 0.0001

def step_decay(epoch):
    initial_lrate = initial_learning_rate
    drop = 0.5
    epochs_drop = 7
    lrate = initial_lrate * (drop ** (epoch // epochs_drop))
    return lrate

def run_train(model, epochs, train, valid):
  early_stopping_patience = 10
  early_stopping = keras.callbacks.EarlyStopping(
      monitor="val_loss", patience=early_stopping_patience, restore_best_weights=True
  )
  lrate_callback = LearningRateScheduler(step_decay)
  # Create a LambdaCallback to print the learning rate at the end of each epoch
  print_lrate = LambdaCallback(on_epoch_end=lambda epoch, logs: print(f"\nLearning Rate at end of epoch {epoch}: {model.optimizer.learning_rate.numpy()}"))
  history = model.fit(
                        train,
                        #steps_per_epoch=train.n // batch_size,
                        epochs=epochs,
                        #batch_size=batch_size,
                        validation_data=valid,
                        callbacks=[early_stopping, lrate_callback, print_lrate],
                        verbose=1,
                        #validation_steps=valid.n // batch_size
                      )
  return history

def call_train(model, train, valid, epochs, batch_size, model_filename, history_filename):
  time_start = time()
  history_train = run_train(model, epochs, train, valid)
  time_train_min = calculate_total_time_min(time_start)
  print('\n')
  show_history_train(history_train)
  print('\n')
  save_model(model, dst_path, model_filename)
  save_history(history_train, dst_path, history_filename)
  return time_train_min

# %% [markdown]
# ##Test

# %% [markdown]
# #####Get Test Labels and predicitions

# %%
def get_true_and_predicted_labels(model, test_data):
  predictions = model.predict(test_data)
  predicted_labels = np.argmax(predictions, axis=1)
  #print(predictions)
  true_labels = []
  # Iterate through the test_data dataset to extract true labels
  for images, labels in test_data:
      true_labels.extend(np.argmax(labels, axis=1))
  # Convert the list of true labels to a NumPy array
  true_labels = np.array(true_labels)

  n_classes = len(np.unique(true_labels))
  return true_labels, predicted_labels, predictions, n_classes

# %% [markdown]
# #####ROC plot

# %%
from sklearn.metrics import roc_curve, auc
def plot_roc(model, test_data):
  fpr = {}
  tpr = {}
  roc_auc = {}

  true_labels, predicted_labels, predictions, n_classes = get_true_and_predicted_labels(model, test_data)
  # Compute ROC curve and ROC area for each class
  for i in range(n_classes):
      fpr[i], tpr[i], _ = roc_curve((true_labels == i).astype(int), predictions[:, i])
      roc_auc[i] = auc(fpr[i], tpr[i])

  # Plot ROC curves
  plt.figure(figsize=(8, 6))
  for i in range(n_classes):
      plt.plot(fpr[i], tpr[i], lw=2, label=f'ROC curve (class {i}) (AUC = {roc_auc[i]:.2f})')

  # Plot random chance line
  plt.plot([0, 1], [0, 1], 'k--', lw=2)

  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('Receiver Operating Characteristic (ROC) Curve')
  plt.legend(loc='lower right')
  plt.show()

# %% [markdown]
# #####Print classes metrics

# %%
from sklearn.metrics import roc_curve, auc
def print_classes_metrics(model, test_data):
  fpr = {}
  tpr = {}
  roc_auc = {}

  true_labels, predicted_labels, predictions, n_classes = get_true_and_predicted_labels(model, test_data)
  # Compute ROC curve and ROC area for each class
  for i in range(n_classes):
      fpr[i], tpr[i], _ = roc_curve((true_labels == i).astype(int), predictions[:, i])
      roc_auc[i] = auc(fpr[i], tpr[i])
      precision[i], recall[i], _ = precision_recall_curve((true_labels == i).astype(int), predictions[:, i])
      f1_score[i] = 2 * (precision[i] * recall[i]) / (precision[i] + recall[i])

      print(f'\n\nClass {i} Metrics')

# %% [markdown]
# #####Confusion Matrix

# %%
import itertools
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix
from PIL import Image

def plot_confusion_matrix(model, test_data):
    # Use the model to predict the values from the test_images.
    test_pred_raw = model.predict(test_data)
    test_pred = np.argmax(test_pred_raw, axis=1)

    y_test = tf.concat([y for x, y in test_data], axis=0)
    test_labels = np.argmax(y_test, axis=1)

    # Calculate the confusion matrix using sklearn.metrics
    cm = confusion_matrix(y_true=test_labels, y_pred=test_pred)

    #print(cm)

    figure = plt.figure(figsize=(8, 8))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(test_data.class_names))
    plt.xticks(tick_marks, test_data.class_names, rotation=45)
    plt.yticks(tick_marks, test_data.class_names)

    # Use white text if squares are dark; otherwise black.
    threshold = cm.max() / 2.

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "white" if cm[i, j] > threshold else "black"
        plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    figure

# %% [markdown]
# #####Run test

# %%
def call_test(model, test_data):
  test_metrics = model.evaluate(test_data)
  print('\n');
  plot_roc(model, test_data)
  print('\n')
  plot_confusion_matrix(model, test_data)
  print('\n')
  return test_metrics

# %% [markdown]
# ##Main

# %% [markdown]
# ###Main code

# %%
def main(model, train, valid, test, learning_rate, batch_size, optimizer_param, optimizer, epochs, layers_config_number, momentum, df_history):
  print('\n\n======================================================================\n')
  print('+++ Trainning and Validation +++',end='\n\n')
  print(f'Epochs: {1} | Optmizer: {optimizer} | Batch size = {batch_size} | Learning rate = {learning_rate} | Momentum = {momentum}|Layers configuration: {layers_config_number} \n\n')
  compile_model(model, optimizer_param)
  filename = f'epochs{epochs}_batch{batch_size}_layers{layers_config_number}_momentum{momentum}'
  model_filename = f'{optimizer}/model_{optimizer}_{filename}'
  history_filename = f'{optimizer}/history_{optimizer}_{filename}'
  time_train_min = call_train(model, train, valid, epochs, batch_size, model_filename, history_filename)
  time_train_hr = round(time_train_min/60, 2)
  time_train_min = round(time_train_min, 2)
  print(f'\nTotal time for trainning and validation: {time_train_min} (min) or {time_train_hr} (hr) \n\n')
  print('\n\n +++ Testing +++ \n')
  test_metrics = call_test(model, test)
  loss = test_metrics[0]
  accuracy = test_metrics[1]
  auc = test_metrics[2]
  precision = test_metrics[3]
  recall = test_metrics[4]
  true_positives  = test_metrics[5]
  true_negatives = test_metrics[6]
  false_positives = test_metrics[7]
  false_negatives = test_metrics[8]
  list = [epochs, optimizer, batch_size, learning_rate , momentum, layers_config_number, time_train_min, time_train_hr,  loss, accuracy, auc, precision, recall, true_positives, true_negatives, false_positives, false_negatives, model_filename, history_filename]
  df_history.loc[len(df_history)] = list
  save_df_history(df_history, optimizer)
  del list, epochs, optimizer, batch_size, learning_rate, layers_config_number, time_train_min, time_train_hr,  loss, accuracy, auc, precision, recall, true_positives, true_negatives, false_positives, false_negatives, model_filename, history_filename, filename

# %% [markdown]
# ###Common values

# %%
epochs = 60
dataset_batch_size_list = ((train_32, valid_32, test_32), (train_64, valid_64, test_64), (train_128, valid_128, test_128))
learning_rate_list = (0.01, 0.001, 0.0001, 0.00001)
momentum_list = (0, 0.9, 0.99)

# %% [markdown]
# ###Optimizer = 'adam'

# %% [markdown]
# ####Model Sequential

# %%
#Store history to insert to sheet
df_history_adam = pd.DataFrame(columns=['Epochs', 'Optmizer', 'Batch_size', 'Learning_rate', 'Momentum','Layers_config', 'Training_time(min)', 'Training_time(hr)' , 'Loss', 'Accuracy', 'Auc', 'Precision', 'Recall', 'True_positives', 'True_negatives', 'False_positives', 'False_negatives','Model_filename' ,'History_filename'])
def call_adam_model():
  optimizer='adam '
  model_adam_print, modelid = model4()
  print(f'\nUsed Model {modelid}:\n')
  model_adam_print.summary()
  print('\n')
  for dataset_batch_size in dataset_batch_size_list:
    #for learning_rate in learning_rate_list:
    train = dataset_batch_size[0]
    valid = dataset_batch_size[1]
    test = dataset_batch_size[2]
    batch_size = get_batch_size(train)
    model_adam, layers_config_adam = model4()
    optimizer_param = keras.optimizers.Adam(learning_rate=initial_learning_rate)
    main(model=model_adam, train=train, valid=valid, test=test, learning_rate='learning_rate', batch_size=batch_size, optimizer_param=optimizer_param, optimizer=optimizer, epochs=epochs, layers_config_number=layers_config_adam, momentum='default', df_history=df_history_adam)

    del model_adam
call_adam_model()
# Out:
# Used Model 4:
#
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_26 (Conv2D)          (None, 300, 300, 32)      896
#
#  max_pooling2d_26 (MaxPooli  (None, 150, 150, 32)      0
#  ng2D)
#
#  conv2d_27 (Conv2D)          (None, 150, 150, 64)      18496
#
#  max_pooling2d_27 (MaxPooli  (None, 75, 75, 64)        0
#  ng2D)
#
#  flatten_13 (Flatten)        (None, 360000)            0
#
#  dense_52 (Dense)            (None, 128)               46080128
#
#  dense_53 (Dense)            (None, 64)                8256
#
#  dense_54 (Dense)            (None, 32)                2080
#
#  dense_55 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 46109955 (175.90 MB)
# Trainable params: 46109955 (175.90 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
#
- categorical_accuracy: 0.9996 - auc_9: 1.0000 - precision_9: 0.9996 - recall_9: 0.9996 - true_positives_9: 2367.0000 - true_negatives_9: 4735.0000 - false_positives_9: 1.0000 - false_negatives_9: 1.0000
# Learning Rate at end of epoch 19: 2.499999936844688e-05
# 75/75 [==============================] - 5s 65ms/step - loss: 0.0020 - categorical_accuracy: 0.9996 - auc_9: 1.0000 - precision_9: 0.9996 - recall_9: 0.9996 - true_positives_9: 2399.0000 - true_negatives_9: 4799.0000 - false_positives_9: 1.0000 - false_negatives_9: 1.0000 - val_loss: 0.3277 - val_categorical_accuracy: 0.9700 - val_auc_9: 0.9805 - val_precision_9: 0.9700 - val_recall_9: 0.9700 - val_true_positives_9: 291.0000 - val_true_negatives_9: 591.0000 - val_false_positives_9: 9.0000 - val_false_negatives_9: 9.0000 - lr: 2.5000e-05
# Epoch 21/60
# 75/75 [==============================] - ETA: 0s - loss: 0.0018 - categorical_accuracy: 1.0000 - auc_9: 1.0000 - precision_9: 1.0000 - recall_9: 1.0000 - true_positives_9: 2400.0000 - true_negatives_9: 4800.0000 - false_positives_9: 0.0000e+00 - false_negatives_9: 0.0000e+00
# Learning Rate at end of epoch 20: 2.499999936844688e-05
# 75/75 [==============================] - 8s 100ms/step - loss: 0.0018 - categorical_accuracy: 1.0000 - auc_9: 1.0000 - precision_9: 1.0000 - recall_9: 1.0000 - true_positives_9: 2400.0000 - true_negatives_9: 4800.0000 - false_positives_9: 0.0000e+00 - false_negatives_9: 0.0000e+00 - val_loss: 0.3266 - val_categorical_accuracy: 0.9700 - val_auc_9: 0.9807 - val_precision_9: 0.9700 - val_recall_9: 0.9700 - val_true_positives_9: 291.0000 - val_true_negatives_9: 591.0000 - val_false_positives_9: 9.0000 - val_false_negatives_9: 9.0000 - lr: 2.5000e-05
# Epoch 22/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0016 - categorical_accuracy: 1.0000 - auc_9: 1.0000 - precision_9: 1.0000 - recall_9: 1.0000 - true_positives_9: 2368.0000 - true_negatives_9: 4736.0000 - false_positives_9: 0.0000e+00 - false_negatives_9: 0.0000e+00
# Learning Rate at end of epoch 21: 1.249999968422344e-05
# 75/75 [==============================] - 4s 54ms/step - loss: 0.0016 - categorical_accuracy: 1.0000 - auc_9: 1.0000 - precision_9: 1.0000 - recall_9: 1.0000 - true_positives_9: 2400.0000 - true_negatives_9: 4800.0000 - false_positives_9: 0.0000e+00 - false_negatives_9: 0.0000e+00 - val_loss: 0.3324 - val_categorical_accuracy: 0.9700 - val_auc_9: 0.9808 - val_precision_9: 0.9700 - val_recall_9: 0.9700 - val_true_positives_9: 291.0000 - val_true_negatives_9: 591.0000 - val_false_positives_9: 9.0000 - val_false_negatives_9: 9.0000 - lr: 1.2500e-05
# Epoch 23/60
# 75/75 [==============================] - ETA: 0s - loss: 0.0016 - categorical_accuracy: 1.0000 - auc_9: 1.0000 - precision_9: 1.0000 - recall_9: 1.0000 - true_positives_9: 2400.0000 - true_negatives_9: 4800.0000 - false_positives_9: 0.0000e+00 - false_negatives_9: 0.0000e+00
# Learning Rate at end of epoch 22: 1.249999968422344e-05
# 75/75 [==============================] - 5s 64ms/step - loss: 0.0016 - categorical_accuracy: 1.0000 - auc_9: 1.0000 - precision_9: 1.0000 - recall_9: 1.0000 - true_positives_9: 2400.0000 - true_negatives_9: 4800.0000 - false_positives_9: 0.0000e+00 - false_negatives_9: 0.0000e+00 - val_loss: 0.3340 - val_categorical_accuracy: 0.9700 - val_auc_9: 0.9808 - val_precision_9: 0.9700 - val_recall_9: 0.9700 - val_true_positives_9: 291.0000 - val_true_negatives_9: 591.0000 - val_false_positives_9: 9.0000 - val_false_negatives_9: 9.0000 - lr: 1.2500e-05
# Epoch 24/60
# 75/75 [==============================] - ETA: 0s - loss: 0.0016 - categorical_accuracy: 1.0000 - auc_9: 1.0000 - precision_9: 1.0000 - recall_9: 1.0000 - true_positives_9: 2400.0000 - true_negatives_9: 4800.0000 - false_positives_9: 0.0000e+00 - false_negatives_9: 0.0000e+00
# Learning Rate at end of epoch 23: 1.249999968422344e-05
# 75/75 [==============================] - 5s 58ms/step - loss: 0.0016 - categorical_accuracy: 1.0000 - auc_9: 1.0000 - precision_9: 1.0000 - recall_9: 1.0000 - true_positives_9: 2400.0000 - true_negatives_9: 4800.0000 - false_positives_9: 0.0000e+00 - false_negatives_9: 0.0000e+00 - val_loss: 0.3347 - val_categorical_accuracy: 0.9700 - val_auc_9: 0.9807 - val_precision_9: 0.9700 - val_recall_9: 0.9700 - val_true_positives_9: 291.0000 - val_true_negatives_9: 591.0000 - val_false_positives_9: 9.0000 - val_false_negatives_9: 9.0000 - lr: 1.2500e-05
# Total time for trainning and validation: 2.36 (min) or 0.04 (hr)
#
#
#
#
#  +++ Testing +++
#
# 10/10 [==============================] - 0s 27ms/step - loss: 0.2401 - categorical_accuracy: 0.9567 - auc_9: 0.9882 - precision_9: 0.9567 - recall_9: 0.9567 - true_positives_9: 287.0000 - true_negatives_9: 587.0000 - false_positives_9: 13.0000 - false_negatives_9: 13.0000
#
#
# 10/10 [==============================] - 0s 26ms/step
# 10/10 [==============================] - 1s 118ms/step
#
#
#
#
# ======================================================================
#
# +++ Trainning and Validation +++
#
# Epochs: 1 | Optmizer: adam  | Batch size = 64 | Learning rate = learning_rate | Momentum = default|Layers configuration: 4
#
#
# Epoch 1/60
# 37/38 [============================>.] - ETA: 0s - loss: 45.8861 - categorical_accuracy: 0.5207 - auc_10: 0.6511 - precision_10: 0.5207 - recall_10: 0.5207 - true_positives_10: 1233.0000 - true_negatives_10: 3601.0000 - false_positives_10: 1135.0000 - false_negatives_10: 1135.0000
# Learning Rate at end of epoch 0: 9.999999747378752e-05
# 38/38 [==============================] - 8s 142ms/step - loss: 45.3119 - categorical_accuracy: 0.5246 - auc_10: 0.6544 - precision_10: 0.5246 - recall_10: 0.5246 - true_positives_10: 1259.0000 - true_negatives_10: 3659.0000 - false_positives_10: 1141.0000 - false_negatives_10: 1141.0000 - val_loss: 4.0027 - val_categorical_accuracy: 0.7167 - val_auc_10: 0.8394 - val_precision_10: 0.7191 - val_recall_10: 0.7167 - val_true_positives_10: 215.0000 - val_true_negatives_10: 516.0000 - val_false_positives_10: 84.0000 - val_false_negatives_10: 85.0000 - lr: 1.0000e-04
# Epoch 2/60
# 37/38 [============================>.] - ETA: 0s - loss: 2.6151 - categorical_accuracy: 0.8003 - auc_10: 0.8806 - precision_10: 0.8005 - recall_10: 0.7998 - true_positives_10: 1894.0000 - true_negatives_10: 4264.0000 - false_positives_10: 472.0000 - false_negatives_10: 474.0000
# Learning Rate at end of epoch 1: 9.999999747378752e-05
# 38/38 [==============================] - 6s 159ms/step - loss: 2.5872 - categorical_accuracy: 0.8012 - auc_10: 0.8818 - precision_10: 0.8015 - recall_10: 0.8008 - true_positives_10: 1922.0000 - true_negatives_10: 4324.0000 - false_positives_10: 476.0000 - false_negatives_10: 478.0000 - val_loss: 1.2617 - val_categorical_accuracy: 0.8700 - val_auc_10: 0.9463 - val_precision_10: 0.8700 - val_recall_10: 0.8700 - val_true_positives_10: 261.0000 - val_true_negatives_10: 561.0000 - val_false_positives_10: 39.0000 - val_false_negatives_10: 39.0000 - lr: 1.0000e-04
# Epoch 3/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.9134 - categorical_accuracy: 0.8737 - auc_10: 0.9482 - precision_10: 0.8737 - recall_10: 0.8737 - true_positives_10: 2069.0000 - true_negatives_10: 4437.0000 - false_positives_10: 299.0000 - false_negatives_10: 299.0000
# Learning Rate at end of epoch 2: 9.999999747378752e-05
# 38/38 [==============================] - 4s 105ms/step - loss: 0.9357 - categorical_accuracy: 0.8721 - auc_10: 0.9475 - precision_10: 0.8721 - recall_10: 0.8721 - true_positives_10: 2093.0000 - true_negatives_10: 4493.0000 - false_positives_10: 307.0000 - false_negatives_10: 307.0000 - val_loss: 1.0027 - val_categorical_accuracy: 0.8233 - val_auc_10: 0.9484 - val_precision_10: 0.8261 - val_recall_10: 0.8233 - val_true_positives_10: 247.0000 - val_true_negatives_10: 548.0000 - val_false_positives_10: 52.0000 - val_false_negatives_10: 53.0000 - lr: 1.0000e-04
# Epoch 4/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.5996 - categorical_accuracy: 0.9050 - auc_10: 0.9623 - precision_10: 0.9054 - recall_10: 0.9050 - true_positives_10: 2143.0000 - true_negatives_10: 4512.0000 - false_positives_10: 224.0000 - false_negatives_10: 225.0000
# Learning Rate at end of epoch 3: 9.999999747378752e-05
# 38/38 [==============================] - 5s 126ms/step - loss: 0.5977 - categorical_accuracy: 0.9046 - auc_10: 0.9622 - precision_10: 0.9050 - recall_10: 0.9046 - true_positives_10: 2171.0000 - true_negatives_10: 4572.0000 - false_positives_10: 228.0000 - false_negatives_10: 229.0000 - val_loss: 0.2249 - val_categorical_accuracy: 0.9500 - val_auc_10: 0.9846 - val_precision_10: 0.9500 - val_recall_10: 0.9500 - val_true_positives_10: 285.0000 - val_true_negatives_10: 585.0000 - val_false_positives_10: 15.0000 - val_false_negatives_10: 15.0000 - lr: 1.0000e-04
# Epoch 5/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.4605 - categorical_accuracy: 0.9139 - auc_10: 0.9725 - precision_10: 0.9142 - recall_10: 0.9139 - true_positives_10: 2164.0000 - true_negatives_10: 4533.0000 - false_positives_10: 203.0000 - false_negatives_10: 204.0000
# Learning Rate at end of epoch 4: 9.999999747378752e-05
# 38/38 [==============================] - 4s 99ms/step - loss: 0.4589 - categorical_accuracy: 0.9142 - auc_10: 0.9726 - precision_10: 0.9149 - recall_10: 0.9142 - true_positives_10: 2194.0000 - true_negatives_10: 4596.0000 - false_positives_10: 204.0000 - false_negatives_10: 206.0000 - val_loss: 0.8025 - val_categorical_accuracy: 0.8800 - val_auc_10: 0.9724 - val_precision_10: 0.8800 - val_recall_10: 0.8800 - val_true_positives_10: 264.0000 - val_true_negatives_10: 564.0000 - val_false_positives_10: 36.0000 - val_false_negatives_10: 36.0000 - lr: 1.0000e-04
# Epoch 6/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.1567 - categorical_accuracy: 0.9616 - auc_10: 0.9916 - precision_10: 0.9616 - recall_10: 0.9616 - true_positives_10: 2277.0000 - true_negatives_10: 4645.0000 - false_positives_10: 91.0000 - false_negatives_10: 91.0000
# Learning Rate at end of epoch 5: 9.999999747378752e-05
# 38/38 [==============================] - 6s 155ms/step - loss: 0.1571 - categorical_accuracy: 0.9617 - auc_10: 0.9914 - precision_10: 0.9617 - recall_10: 0.9617 - true_positives_10: 2308.0000 - true_negatives_10: 4708.0000 - false_positives_10: 92.0000 - false_negatives_10: 92.0000 - val_loss: 0.2830 - val_categorical_accuracy: 0.9700 - val_auc_10: 0.9808 - val_precision_10: 0.9700 - val_recall_10: 0.9700 - val_true_positives_10: 291.0000 - val_true_negatives_10: 591.0000 - val_false_positives_10: 9.0000 - val_false_negatives_10: 9.0000 - lr: 1.0000e-04
# Epoch 7/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.3377 - categorical_accuracy: 0.9324 - auc_10: 0.9794 - precision_10: 0.9324 - recall_10: 0.9320 - true_positives_10: 2207.0000 - true_negatives_10: 4576.0000 - false_positives_10: 160.0000 - false_negatives_10: 161.0000
# Learning Rate at end of epoch 6: 9.999999747378752e-05
# 38/38 [==============================] - 5s 133ms/step - loss: 0.3370 - categorical_accuracy: 0.9325 - auc_10: 0.9793 - precision_10: 0.9325 - recall_10: 0.9321 - true_positives_10: 2237.0000 - true_negatives_10: 4638.0000 - false_positives_10: 162.0000 - false_negatives_10: 163.0000 - val_loss: 0.6074 - val_categorical_accuracy: 0.9033 - val_auc_10: 0.9712 - val_precision_10: 0.9033 - val_recall_10: 0.9033 - val_true_positives_10: 271.0000 - val_true_negatives_10: 571.0000 - val_false_positives_10: 29.0000 - val_false_negatives_10: 29.0000 - lr: 1.0000e-04
# Epoch 8/60
# 38/38 [==============================] - ETA: 0s - loss: 0.1023 - categorical_accuracy: 0.9754 - auc_10: 0.9951 - precision_10: 0.9754 - recall_10: 0.9754 - true_positives_10: 2341.0000 - true_negatives_10: 4741.0000 - false_positives_10: 59.0000 - false_negatives_10: 59.0000
# Learning Rate at end of epoch 7: 4.999999873689376e-05
# 38/38 [==============================] - 5s 136ms/step - loss: 0.1023 - categorical_accuracy: 0.9754 - auc_10: 0.9951 - precision_10: 0.9754 - recall_10: 0.9754 - true_positives_10: 2341.0000 - true_negatives_10: 4741.0000 - false_positives_10: 59.0000 - false_negatives_10: 59.0000 - val_loss: 0.3002 - val_categorical_accuracy: 0.9333 - val_auc_10: 0.9845 - val_precision_10: 0.9333 - val_recall_10: 0.9333 - val_true_positives_10: 280.0000 - val_true_negatives_10: 580.0000 - val_false_positives_10: 20.0000 - val_false_negatives_10: 20.0000 - lr: 5.0000e-05
# Epoch 9/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0825 - categorical_accuracy: 0.9835 - auc_10: 0.9960 - precision_10: 0.9835 - recall_10: 0.9835 - true_positives_10: 2329.0000 - true_negatives_10: 4697.0000 - false_positives_10: 39.0000 - false_negatives_10: 39.0000
# Learning Rate at end of epoch 8: 4.999999873689376e-05
# 38/38 [==============================] - 4s 108ms/step - loss: 0.0814 - categorical_accuracy: 0.9837 - auc_10: 0.9960 - precision_10: 0.9837 - recall_10: 0.9837 - true_positives_10: 2361.0000 - true_negatives_10: 4761.0000 - false_positives_10: 39.0000 - false_negatives_10: 39.0000 - val_loss: 0.2291 - val_categorical_accuracy: 0.9433 - val_auc_10: 0.9874 - val_precision_10: 0.9433 - val_recall_10: 0.9433 - val_true_positives_10: 283.0000 - val_true_negatives_10: 583.0000 - val_false_positives_10: 17.0000 - val_false_negatives_10: 17.0000 - lr: 5.0000e-05
# Epoch 10/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0353 - categorical_accuracy: 0.9890 - auc_10: 0.9985 - precision_10: 0.9890 - recall_10: 0.9890 - true_positives_10: 2342.0000 - true_negatives_10: 4710.0000 - false_positives_10: 26.0000 - false_negatives_10: 26.0000
# Learning Rate at end of epoch 9: 4.999999873689376e-05
# 38/38 [==============================] - 5s 120ms/step - loss: 0.0349 - categorical_accuracy: 0.9892 - auc_10: 0.9986 - precision_10: 0.9892 - recall_10: 0.9892 - true_positives_10: 2374.0000 - true_negatives_10: 4774.0000 - false_positives_10: 26.0000 - false_negatives_10: 26.0000 - val_loss: 0.2437 - val_categorical_accuracy: 0.9600 - val_auc_10: 0.9854 - val_precision_10: 0.9600 - val_recall_10: 0.9600 - val_true_positives_10: 288.0000 - val_true_negatives_10: 588.0000 - val_false_positives_10: 12.0000 - val_false_negatives_10: 12.0000 - lr: 5.0000e-05
# Epoch 11/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0274 - categorical_accuracy: 0.9924 - auc_10: 0.9993 - precision_10: 0.9924 - recall_10: 0.9924 - true_positives_10: 2350.0000 - true_negatives_10: 4718.0000 - false_positives_10: 18.0000 - false_negatives_10: 18.0000
# Learning Rate at end of epoch 10: 4.999999873689376e-05
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0270 - categorical_accuracy: 0.9925 - auc_10: 0.9993 - precision_10: 0.9925 - recall_10: 0.9925 - true_positives_10: 2382.0000 - true_negatives_10: 4782.0000 - false_positives_10: 18.0000 - false_negatives_10: 18.0000 - val_loss: 0.2577 - val_categorical_accuracy: 0.9633 - val_auc_10: 0.9855 - val_precision_10: 0.9633 - val_recall_10: 0.9633 - val_true_positives_10: 289.0000 - val_true_negatives_10: 589.0000 - val_false_positives_10: 11.0000 - val_false_negatives_10: 11.0000 - lr: 5.0000e-05
# Epoch 12/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0268 - categorical_accuracy: 0.9890 - auc_10: 0.9989 - precision_10: 0.9890 - recall_10: 0.9890 - true_positives_10: 2342.0000 - true_negatives_10: 4710.0000 - false_positives_10: 26.0000 - false_negatives_10: 26.0000
# Learning Rate at end of epoch 11: 4.999999873689376e-05
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0269 - categorical_accuracy: 0.9892 - auc_10: 0.9989 - precision_10: 0.9892 - recall_10: 0.9892 - true_positives_10: 2374.0000 - true_negatives_10: 4774.0000 - false_positives_10: 26.0000 - false_negatives_10: 26.0000 - val_loss: 0.1918 - val_categorical_accuracy: 0.9600 - val_auc_10: 0.9870 - val_precision_10: 0.9600 - val_recall_10: 0.9600 - val_true_positives_10: 288.0000 - val_true_negatives_10: 588.0000 - val_false_positives_10: 12.0000 - val_false_negatives_10: 12.0000 - lr: 5.0000e-05
# Epoch 13/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0084 - categorical_accuracy: 0.9966 - auc_10: 1.0000 - precision_10: 0.9966 - recall_10: 0.9966 - true_positives_10: 2360.0000 - true_negatives_10: 4728.0000 - false_positives_10: 8.0000 - false_negatives_10: 8.0000
# Learning Rate at end of epoch 12: 4.999999873689376e-05
# 38/38 [==============================] - 6s 162ms/step - loss: 0.0083 - categorical_accuracy: 0.9967 - auc_10: 1.0000 - precision_10: 0.9967 - recall_10: 0.9967 - true_positives_10: 2392.0000 - true_negatives_10: 4792.0000 - false_positives_10: 8.0000 - false_negatives_10: 8.0000 - val_loss: 0.2471 - val_categorical_accuracy: 0.9600 - val_auc_10: 0.9830 - val_precision_10: 0.9600 - val_recall_10: 0.9600 - val_true_positives_10: 288.0000 - val_true_negatives_10: 588.0000 - val_false_positives_10: 12.0000 - val_false_negatives_10: 12.0000 - lr: 5.0000e-05
# Epoch 14/60
# 38/38 [==============================] - ETA: 0s - loss: 0.0047 - categorical_accuracy: 0.9987 - auc_10: 1.0000 - precision_10: 0.9987 - recall_10: 0.9987 - true_positives_10: 2397.0000 - true_negatives_10: 4797.0000 - false_positives_10: 3.0000 - false_negatives_10: 3.0000
# Learning Rate at end of epoch 13: 4.999999873689376e-05
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0047 - categorical_accuracy: 0.9987 - auc_10: 1.0000 - precision_10: 0.9987 - recall_10: 0.9987 - true_positives_10: 2397.0000 - true_negatives_10: 4797.0000 - false_positives_10: 3.0000 - false_negatives_10: 3.0000 - val_loss: 0.2104 - val_categorical_accuracy: 0.9600 - val_auc_10: 0.9877 - val_precision_10: 0.9600 - val_recall_10: 0.9600 - val_true_positives_10: 288.0000 - val_true_negatives_10: 588.0000 - val_false_positives_10: 12.0000 - val_false_negatives_10: 12.0000 - lr: 5.0000e-05
# Epoch 15/60
# 38/38 [==============================] - ETA: 0s - loss: 0.0033 - categorical_accuracy: 0.9992 - auc_10: 1.0000 - precision_10: 0.9992 - recall_10: 0.9992 - true_positives_10: 2398.0000 - true_negatives_10: 4798.0000 - false_positives_10: 2.0000 - false_negatives_10: 2.0000
# Learning Rate at end of epoch 14: 2.499999936844688e-05
# 38/38 [==============================] - 5s 117ms/step - loss: 0.0033 - categorical_accuracy: 0.9992 - auc_10: 1.0000 - precision_10: 0.9992 - recall_10: 0.9992 - true_positives_10: 2398.0000 - true_negatives_10: 4798.0000 - false_positives_10: 2.0000 - false_negatives_10: 2.0000 - val_loss: 0.2140 - val_categorical_accuracy: 0.9633 - val_auc_10: 0.9878 - val_precision_10: 0.9633 - val_recall_10: 0.9633 - val_true_positives_10: 289.0000 - val_true_negatives_10: 589.0000 - val_false_positives_10: 11.0000 - val_false_negatives_10: 11.0000 - lr: 2.5000e-05
# Epoch 16/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0022 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2368.0000 - true_negatives_10: 4736.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00
# Learning Rate at end of epoch 15: 2.499999936844688e-05
# 38/38 [==============================] - 5s 132ms/step - loss: 0.0022 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2400.0000 - true_negatives_10: 4800.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00 - val_loss: 0.1893 - val_categorical_accuracy: 0.9633 - val_auc_10: 0.9879 - val_precision_10: 0.9633 - val_recall_10: 0.9633 - val_true_positives_10: 289.0000 - val_true_negatives_10: 589.0000 - val_false_positives_10: 11.0000 - val_false_negatives_10: 11.0000 - lr: 2.5000e-05
# Epoch 17/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0020 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2368.0000 - true_negatives_10: 4736.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00
# Learning Rate at end of epoch 16: 2.499999936844688e-05
# 38/38 [==============================] - 4s 84ms/step - loss: 0.0020 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2400.0000 - true_negatives_10: 4800.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00 - val_loss: 0.1919 - val_categorical_accuracy: 0.9633 - val_auc_10: 0.9879 - val_precision_10: 0.9633 - val_recall_10: 0.9633 - val_true_positives_10: 289.0000 - val_true_negatives_10: 589.0000 - val_false_positives_10: 11.0000 - val_false_negatives_10: 11.0000 - lr: 2.5000e-05
# Epoch 18/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0021 - categorical_accuracy: 0.9996 - auc_10: 1.0000 - precision_10: 0.9996 - recall_10: 0.9996 - true_positives_10: 2367.0000 - true_negatives_10: 4735.0000 - false_positives_10: 1.0000 - false_negatives_10: 1.0000
# Learning Rate at end of epoch 17: 2.499999936844688e-05
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0020 - categorical_accuracy: 0.9996 - auc_10: 1.0000 - precision_10: 0.9996 - recall_10: 0.9996 - true_positives_10: 2399.0000 - true_negatives_10: 4799.0000 - false_positives_10: 1.0000 - false_negatives_10: 1.0000 - val_loss: 0.1984 - val_categorical_accuracy: 0.9633 - val_auc_10: 0.9900 - val_precision_10: 0.9633 - val_recall_10: 0.9633 - val_true_positives_10: 289.0000 - val_true_negatives_10: 589.0000 - val_false_positives_10: 11.0000 - val_false_negatives_10: 11.0000 - lr: 2.5000e-05
# Epoch 19/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0019 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2368.0000 - true_negatives_10: 4736.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00
# Learning Rate at end of epoch 18: 2.499999936844688e-05
# 38/38 [==============================] - 5s 117ms/step - loss: 0.0019 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2400.0000 - true_negatives_10: 4800.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00 - val_loss: 0.1920 - val_categorical_accuracy: 0.9633 - val_auc_10: 0.9878 - val_precision_10: 0.9633 - val_recall_10: 0.9633 - val_true_positives_10: 289.0000 - val_true_negatives_10: 589.0000 - val_false_positives_10: 11.0000 - val_false_negatives_10: 11.0000 - lr: 2.5000e-05
# Epoch 20/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0014 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2368.0000 - true_negatives_10: 4736.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00
# Learning Rate at end of epoch 19: 2.499999936844688e-05
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0014 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2400.0000 - true_negatives_10: 4800.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00 - val_loss: 0.2004 - val_categorical_accuracy: 0.9600 - val_auc_10: 0.9878 - val_precision_10: 0.9600 - val_recall_10: 0.9600 - val_true_positives_10: 288.0000 - val_true_negatives_10: 588.0000 - val_false_positives_10: 12.0000 - val_false_negatives_10: 12.0000 - lr: 2.5000e-05
# Epoch 21/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0014 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2368.0000 - true_negatives_10: 4736.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00
# Learning Rate at end of epoch 20: 2.499999936844688e-05
# 38/38 [==============================] - 7s 163ms/step - loss: 0.0014 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2400.0000 - true_negatives_10: 4800.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00 - val_loss: 0.1948 - val_categorical_accuracy: 0.9600 - val_auc_10: 0.9880 - val_precision_10: 0.9600 - val_recall_10: 0.9600 - val_true_positives_10: 288.0000 - val_true_negatives_10: 588.0000 - val_false_positives_10: 12.0000 - val_false_negatives_10: 12.0000 - lr: 2.5000e-05
# Epoch 22/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0012 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2368.0000 - true_negatives_10: 4736.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00
# Learning Rate at end of epoch 21: 1.249999968422344e-05
# 38/38 [==============================] - 5s 127ms/step - loss: 0.0012 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2400.0000 - true_negatives_10: 4800.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00 - val_loss: 0.1994 - val_categorical_accuracy: 0.9600 - val_auc_10: 0.9879 - val_precision_10: 0.9600 - val_recall_10: 0.9600 - val_true_positives_10: 288.0000 - val_true_negatives_10: 588.0000 - val_false_positives_10: 12.0000 - val_false_negatives_10: 12.0000 - lr: 1.2500e-05
# Epoch 23/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0012 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2368.0000 - true_negatives_10: 4736.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00
# Learning Rate at end of epoch 22: 1.249999968422344e-05
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0012 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2400.0000 - true_negatives_10: 4800.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00 - val_loss: 0.1994 - val_categorical_accuracy: 0.9600 - val_auc_10: 0.9878 - val_precision_10: 0.9600 - val_recall_10: 0.9600 - val_true_positives_10: 288.0000 - val_true_negatives_10: 588.0000 - val_false_positives_10: 12.0000 - val_false_negatives_10: 12.0000 - lr: 1.2500e-05
# Epoch 24/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0011 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2368.0000 - true_negatives_10: 4736.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00
# Learning Rate at end of epoch 23: 1.249999968422344e-05
# 38/38 [==============================] - 5s 114ms/step - loss: 0.0011 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2400.0000 - true_negatives_10: 4800.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00 - val_loss: 0.2005 - val_categorical_accuracy: 0.9600 - val_auc_10: 0.9879 - val_precision_10: 0.9600 - val_recall_10: 0.9600 - val_true_positives_10: 288.0000 - val_true_negatives_10: 588.0000 - val_false_positives_10: 12.0000 - val_false_negatives_10: 12.0000 - lr: 1.2500e-05
# Epoch 25/60
# 37/38 [============================>.] - ETA: 0s - loss: 0.0010 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2368.0000 - true_negatives_10: 4736.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00
# Learning Rate at end of epoch 24: 1.249999968422344e-05
# 38/38 [==============================] - 6s 159ms/step - loss: 0.0011 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2400.0000 - true_negatives_10: 4800.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00 - val_loss: 0.2024 - val_categorical_accuracy: 0.9600 - val_auc_10: 0.9879 - val_precision_10: 0.9600 - val_recall_10: 0.9600 - val_true_positives_10: 288.0000 - val_true_negatives_10: 588.0000 - val_false_positives_10: 12.0000 - val_false_negatives_10: 12.0000 - lr: 1.2500e-05
# Epoch 26/60
# 38/38 [==============================] - ETA: 0s - loss: 0.0010 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2400.0000 - true_negatives_10: 4800.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00
# Learning Rate at end of epoch 25: 1.249999968422344e-05
# 38/38 [==============================] - 6s 149ms/step - loss: 0.0010 - categorical_accuracy: 1.0000 - auc_10: 1.0000 - precision_10: 1.0000 - recall_10: 1.0000 - true_positives_10: 2400.0000 - true_negatives_10: 4800.0000 - false_positives_10: 0.0000e+00 - false_negatives_10: 0.0000e+00 - val_loss: 0.2029 - val_categorical_accuracy: 0.9600 - val_auc_10: 0.9879 - val_precision_10: 0.9600 - val_recall_10: 0.9600 - val_true_positives_10: 288.0000 - val_true_negatives_10: 588.0000 - val_false_positives_10: 12.0000 - val_false_negatives_10: 12.0000 - lr: 1.2500e-05
# Total time for trainning and validation: 2.37 (min) or 0.04 (hr)
#
#
#
#
#  +++ Testing +++
#
# ...
# Epoch 7/60
# 19/19 [==============================] - ETA: 0s - loss: 0.1658 - categorical_accuracy: 0.9479 - auc_11: 0.9909 - precision_11: 0.9483 - recall_11: 0.9471 - true_positives_11: 2273.0000 - true_negatives_11: 4676.0000 - false_positives_11: 124.0000 - false_negatives_11: 127.0000
# Learning Rate at end of epoch 6: 9.999999747378752e-05
# 19/19 [==============================] - 5s 199ms/step - loss: 0.1658 - categorical_accuracy: 0.9479 - auc_11: 0.9909 - precision_11: 0.9483 - recall_11: 0.9471 - true_positives_11: 2273.0000 - true_negatives_11: 4676.0000 - false_positives_11: 124.0000 - false_negatives_11: 127.0000 - val_loss: 0.4019 - val_categorical_accuracy: 0.8900 - val_auc_11: 0.9783 - val_precision_11: 0.8900 - val_recall_11: 0.8900 - val_true_positives_11: 267.0000 - val_true_negatives_11: 567.0000 - val_false_positives_11: 33.0000 - val_false_negatives_11: 33.0000 - lr: 1.0000e-04
# Epoch 8/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0756 - categorical_accuracy: 0.9725 - auc_11: 0.9975 - precision_11: 0.9733 - recall_11: 0.9725 - true_positives_11: 2334.0000 - true_negatives_11: 4736.0000 - false_positives_11: 64.0000 - false_negatives_11: 66.0000
# Learning Rate at end of epoch 7: 4.999999873689376e-05
# 19/19 [==============================] - 6s 279ms/step - loss: 0.0756 - categorical_accuracy: 0.9725 - auc_11: 0.9975 - precision_11: 0.9733 - recall_11: 0.9725 - true_positives_11: 2334.0000 - true_negatives_11: 4736.0000 - false_positives_11: 64.0000 - false_negatives_11: 66.0000 - val_loss: 0.2778 - val_categorical_accuracy: 0.9167 - val_auc_11: 0.9832 - val_precision_11: 0.9167 - val_recall_11: 0.9167 - val_true_positives_11: 275.0000 - val_true_negatives_11: 575.0000 - val_false_positives_11: 25.0000 - val_false_negatives_11: 25.0000 - lr: 5.0000e-05
# Epoch 9/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0601 - categorical_accuracy: 0.9750 - auc_11: 0.9985 - precision_11: 0.9762 - recall_11: 0.9746 - true_positives_11: 2339.0000 - true_negatives_11: 4743.0000 - false_positives_11: 57.0000 - false_negatives_11: 61.0000
# Learning Rate at end of epoch 8: 4.999999873689376e-05
# 19/19 [==============================] - 4s 197ms/step - loss: 0.0601 - categorical_accuracy: 0.9750 - auc_11: 0.9985 - precision_11: 0.9762 - recall_11: 0.9746 - true_positives_11: 2339.0000 - true_negatives_11: 4743.0000 - false_positives_11: 57.0000 - false_negatives_11: 61.0000 - val_loss: 0.2980 - val_categorical_accuracy: 0.9467 - val_auc_11: 0.9820 - val_precision_11: 0.9467 - val_recall_11: 0.9467 - val_true_positives_11: 284.0000 - val_true_negatives_11: 584.0000 - val_false_positives_11: 16.0000 - val_false_negatives_11: 16.0000 - lr: 5.0000e-05
# Epoch 10/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0410 - categorical_accuracy: 0.9825 - auc_11: 0.9995 - precision_11: 0.9825 - recall_11: 0.9821 - true_positives_11: 2357.0000 - true_negatives_11: 4758.0000 - false_positives_11: 42.0000 - false_negatives_11: 43.0000
# Learning Rate at end of epoch 9: 4.999999873689376e-05
# 19/19 [==============================] - 5s 207ms/step - loss: 0.0410 - categorical_accuracy: 0.9825 - auc_11: 0.9995 - precision_11: 0.9825 - recall_11: 0.9821 - true_positives_11: 2357.0000 - true_negatives_11: 4758.0000 - false_positives_11: 42.0000 - false_negatives_11: 43.0000 - val_loss: 0.2627 - val_categorical_accuracy: 0.9300 - val_auc_11: 0.9829 - val_precision_11: 0.9331 - val_recall_11: 0.9300 - val_true_positives_11: 279.0000 - val_true_negatives_11: 580.0000 - val_false_positives_11: 20.0000 - val_false_negatives_11: 21.0000 - lr: 5.0000e-05
# Epoch 11/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0322 - categorical_accuracy: 0.9871 - auc_11: 0.9997 - precision_11: 0.9875 - recall_11: 0.9867 - true_positives_11: 2368.0000 - true_negatives_11: 4770.0000 - false_positives_11: 30.0000 - false_negatives_11: 32.0000
# Learning Rate at end of epoch 10: 4.999999873689376e-05
# 19/19 [==============================] - 6s 283ms/step - loss: 0.0322 - categorical_accuracy: 0.9871 - auc_11: 0.9997 - precision_11: 0.9875 - recall_11: 0.9867 - true_positives_11: 2368.0000 - true_negatives_11: 4770.0000 - false_positives_11: 30.0000 - false_negatives_11: 32.0000 - val_loss: 0.2482 - val_categorical_accuracy: 0.9200 - val_auc_11: 0.9841 - val_precision_11: 0.9200 - val_recall_11: 0.9200 - val_true_positives_11: 276.0000 - val_true_negatives_11: 576.0000 - val_false_positives_11: 24.0000 - val_false_negatives_11: 24.0000 - lr: 5.0000e-05
# Epoch 12/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0287 - categorical_accuracy: 0.9887 - auc_11: 0.9998 - precision_11: 0.9887 - recall_11: 0.9887 - true_positives_11: 2373.0000 - true_negatives_11: 4773.0000 - false_positives_11: 27.0000 - false_negatives_11: 27.0000
# Learning Rate at end of epoch 11: 4.999999873689376e-05
# 19/19 [==============================] - 4s 197ms/step - loss: 0.0287 - categorical_accuracy: 0.9887 - auc_11: 0.9998 - precision_11: 0.9887 - recall_11: 0.9887 - true_positives_11: 2373.0000 - true_negatives_11: 4773.0000 - false_positives_11: 27.0000 - false_negatives_11: 27.0000 - val_loss: 0.2856 - val_categorical_accuracy: 0.9167 - val_auc_11: 0.9819 - val_precision_11: 0.9167 - val_recall_11: 0.9167 - val_true_positives_11: 275.0000 - val_true_negatives_11: 575.0000 - val_false_positives_11: 25.0000 - val_false_negatives_11: 25.0000 - lr: 5.0000e-05
# Epoch 13/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0217 - categorical_accuracy: 0.9921 - auc_11: 0.9999 - precision_11: 0.9921 - recall_11: 0.9917 - true_positives_11: 2380.0000 - true_negatives_11: 4781.0000 - false_positives_11: 19.0000 - false_negatives_11: 20.0000
# Learning Rate at end of epoch 12: 4.999999873689376e-05
# 19/19 [==============================] - 5s 237ms/step - loss: 0.0217 - categorical_accuracy: 0.9921 - auc_11: 0.9999 - precision_11: 0.9921 - recall_11: 0.9917 - true_positives_11: 2380.0000 - true_negatives_11: 4781.0000 - false_positives_11: 19.0000 - false_negatives_11: 20.0000 - val_loss: 0.2343 - val_categorical_accuracy: 0.9367 - val_auc_11: 0.9868 - val_precision_11: 0.9365 - val_recall_11: 0.9333 - val_true_positives_11: 280.0000 - val_true_negatives_11: 581.0000 - val_false_positives_11: 19.0000 - val_false_negatives_11: 20.0000 - lr: 5.0000e-05
# Epoch 14/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0188 - categorical_accuracy: 0.9929 - auc_11: 0.9999 - precision_11: 0.9929 - recall_11: 0.9925 - true_positives_11: 2382.0000 - true_negatives_11: 4783.0000 - false_positives_11: 17.0000 - false_negatives_11: 18.0000
# Learning Rate at end of epoch 13: 4.999999873689376e-05
# 19/19 [==============================] - 5s 212ms/step - loss: 0.0188 - categorical_accuracy: 0.9929 - auc_11: 0.9999 - precision_11: 0.9929 - recall_11: 0.9925 - true_positives_11: 2382.0000 - true_negatives_11: 4783.0000 - false_positives_11: 17.0000 - false_negatives_11: 18.0000 - val_loss: 0.2527 - val_categorical_accuracy: 0.9333 - val_auc_11: 0.9859 - val_precision_11: 0.9333 - val_recall_11: 0.9333 - val_true_positives_11: 280.0000 - val_true_negatives_11: 580.0000 - val_false_positives_11: 20.0000 - val_false_negatives_11: 20.0000 - lr: 5.0000e-05
# Epoch 15/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0141 - categorical_accuracy: 0.9950 - auc_11: 1.0000 - precision_11: 0.9958 - recall_11: 0.9950 - true_positives_11: 2388.0000 - true_negatives_11: 4790.0000 - false_positives_11: 10.0000 - false_negatives_11: 12.0000
# Learning Rate at end of epoch 14: 2.499999936844688e-05
# 19/19 [==============================] - 5s 230ms/step - loss: 0.0141 - categorical_accuracy: 0.9950 - auc_11: 1.0000 - precision_11: 0.9958 - recall_11: 0.9950 - true_positives_11: 2388.0000 - true_negatives_11: 4790.0000 - false_positives_11: 10.0000 - false_negatives_11: 12.0000 - val_loss: 0.2362 - val_categorical_accuracy: 0.9333 - val_auc_11: 0.9869 - val_precision_11: 0.9333 - val_recall_11: 0.9333 - val_true_positives_11: 280.0000 - val_true_negatives_11: 580.0000 - val_false_positives_11: 20.0000 - val_false_negatives_11: 20.0000 - lr: 2.5000e-05
# Epoch 16/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0126 - categorical_accuracy: 0.9967 - auc_11: 1.0000 - precision_11: 0.9967 - recall_11: 0.9962 - true_positives_11: 2391.0000 - true_negatives_11: 4792.0000 - false_positives_11: 8.0000 - false_negatives_11: 9.0000
# Learning Rate at end of epoch 15: 2.499999936844688e-05
# 19/19 [==============================] - 5s 194ms/step - loss: 0.0126 - categorical_accuracy: 0.9967 - auc_11: 1.0000 - precision_11: 0.9967 - recall_11: 0.9962 - true_positives_11: 2391.0000 - true_negatives_11: 4792.0000 - false_positives_11: 8.0000 - false_negatives_11: 9.0000 - val_loss: 0.2408 - val_categorical_accuracy: 0.9367 - val_auc_11: 0.9864 - val_precision_11: 0.9396 - val_recall_11: 0.9333 - val_true_positives_11: 280.0000 - val_true_negatives_11: 582.0000 - val_false_positives_11: 18.0000 - val_false_negatives_11: 20.0000 - lr: 2.5000e-05
# Epoch 17/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0125 - categorical_accuracy: 0.9954 - auc_11: 1.0000 - precision_11: 0.9958 - recall_11: 0.9954 - true_positives_11: 2389.0000 - true_negatives_11: 4790.0000 - false_positives_11: 10.0000 - false_negatives_11: 11.0000
# Learning Rate at end of epoch 16: 2.499999936844688e-05
# 19/19 [==============================] - 7s 358ms/step - loss: 0.0125 - categorical_accuracy: 0.9954 - auc_11: 1.0000 - precision_11: 0.9958 - recall_11: 0.9954 - true_positives_11: 2389.0000 - true_negatives_11: 4790.0000 - false_positives_11: 10.0000 - false_negatives_11: 11.0000 - val_loss: 0.2436 - val_categorical_accuracy: 0.9300 - val_auc_11: 0.9843 - val_precision_11: 0.9331 - val_recall_11: 0.9300 - val_true_positives_11: 279.0000 - val_true_negatives_11: 580.0000 - val_false_positives_11: 20.0000 - val_false_negatives_11: 21.0000 - lr: 2.5000e-05
# Epoch 18/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0111 - categorical_accuracy: 0.9975 - auc_11: 1.0000 - precision_11: 0.9979 - recall_11: 0.9975 - true_positives_11: 2394.0000 - true_negatives_11: 4795.0000 - false_positives_11: 5.0000 - false_negatives_11: 6.0000
# Learning Rate at end of epoch 17: 2.499999936844688e-05
# 19/19 [==============================] - 6s 288ms/step - loss: 0.0111 - categorical_accuracy: 0.9975 - auc_11: 1.0000 - precision_11: 0.9979 - recall_11: 0.9975 - true_positives_11: 2394.0000 - true_negatives_11: 4795.0000 - false_positives_11: 5.0000 - false_negatives_11: 6.0000 - val_loss: 0.2443 - val_categorical_accuracy: 0.9333 - val_auc_11: 0.9845 - val_precision_11: 0.9333 - val_recall_11: 0.9333 - val_true_positives_11: 280.0000 - val_true_negatives_11: 580.0000 - val_false_positives_11: 20.0000 - val_false_negatives_11: 20.0000 - lr: 2.5000e-05
# Epoch 19/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0117 - categorical_accuracy: 0.9962 - auc_11: 1.0000 - precision_11: 0.9962 - recall_11: 0.9958 - true_positives_11: 2390.0000 - true_negatives_11: 4791.0000 - false_positives_11: 9.0000 - false_negatives_11: 10.0000
# Learning Rate at end of epoch 18: 2.499999936844688e-05
# 19/19 [==============================] - 4s 195ms/step - loss: 0.0117 - categorical_accuracy: 0.9962 - auc_11: 1.0000 - precision_11: 0.9962 - recall_11: 0.9958 - true_positives_11: 2390.0000 - true_negatives_11: 4791.0000 - false_positives_11: 9.0000 - false_negatives_11: 10.0000 - val_loss: 0.2434 - val_categorical_accuracy: 0.9400 - val_auc_11: 0.9864 - val_precision_11: 0.9398 - val_recall_11: 0.9367 - val_true_positives_11: 281.0000 - val_true_negatives_11: 582.0000 - val_false_positives_11: 18.0000 - val_false_negatives_11: 19.0000 - lr: 2.5000e-05
# Epoch 20/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0115 - categorical_accuracy: 0.9962 - auc_11: 1.0000 - precision_11: 0.9962 - recall_11: 0.9962 - true_positives_11: 2391.0000 - true_negatives_11: 4791.0000 - false_positives_11: 9.0000 - false_negatives_11: 9.0000
# Learning Rate at end of epoch 19: 2.499999936844688e-05
# 19/19 [==============================] - 6s 263ms/step - loss: 0.0115 - categorical_accuracy: 0.9962 - auc_11: 1.0000 - precision_11: 0.9962 - recall_11: 0.9962 - true_positives_11: 2391.0000 - true_negatives_11: 4791.0000 - false_positives_11: 9.0000 - false_negatives_11: 9.0000 - val_loss: 0.2433 - val_categorical_accuracy: 0.9333 - val_auc_11: 0.9872 - val_precision_11: 0.9333 - val_recall_11: 0.9333 - val_true_positives_11: 280.0000 - val_true_negatives_11: 580.0000 - val_false_positives_11: 20.0000 - val_false_negatives_11: 20.0000 - lr: 2.5000e-05
# Epoch 21/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0106 - categorical_accuracy: 0.9971 - auc_11: 1.0000 - precision_11: 0.9971 - recall_11: 0.9971 - true_positives_11: 2393.0000 - true_negatives_11: 4793.0000 - false_positives_11: 7.0000 - false_negatives_11: 7.0000
# Learning Rate at end of epoch 20: 2.499999936844688e-05
# 19/19 [==============================] - 6s 286ms/step - loss: 0.0106 - categorical_accuracy: 0.9971 - auc_11: 1.0000 - precision_11: 0.9971 - recall_11: 0.9971 - true_positives_11: 2393.0000 - true_negatives_11: 4793.0000 - false_positives_11: 7.0000 - false_negatives_11: 7.0000 - val_loss: 0.2385 - val_categorical_accuracy: 0.9300 - val_auc_11: 0.9867 - val_precision_11: 0.9331 - val_recall_11: 0.9300 - val_true_positives_11: 279.0000 - val_true_negatives_11: 580.0000 - val_false_positives_11: 20.0000 - val_false_negatives_11: 21.0000 - lr: 2.5000e-05
# Epoch 22/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0091 - categorical_accuracy: 0.9979 - auc_11: 1.0000 - precision_11: 0.9979 - recall_11: 0.9975 - true_positives_11: 2394.0000 - true_negatives_11: 4795.0000 - false_positives_11: 5.0000 - false_negatives_11: 6.0000
# Learning Rate at end of epoch 21: 1.249999968422344e-05
# 19/19 [==============================] - 5s 232ms/step - loss: 0.0091 - categorical_accuracy: 0.9979 - auc_11: 1.0000 - precision_11: 0.9979 - recall_11: 0.9975 - true_positives_11: 2394.0000 - true_negatives_11: 4795.0000 - false_positives_11: 5.0000 - false_negatives_11: 6.0000 - val_loss: 0.2431 - val_categorical_accuracy: 0.9333 - val_auc_11: 0.9869 - val_precision_11: 0.9365 - val_recall_11: 0.9333 - val_true_positives_11: 280.0000 - val_true_negatives_11: 581.0000 - val_false_positives_11: 19.0000 - val_false_negatives_11: 20.0000 - lr: 1.2500e-05
# Epoch 23/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0089 - categorical_accuracy: 0.9971 - auc_11: 1.0000 - precision_11: 0.9975 - recall_11: 0.9971 - true_positives_11: 2393.0000 - true_negatives_11: 4794.0000 - false_positives_11: 6.0000 - false_negatives_11: 7.0000
# Learning Rate at end of epoch 22: 1.249999968422344e-05
# 19/19 [==============================] - 6s 259ms/step - loss: 0.0089 - categorical_accuracy: 0.9971 - auc_11: 1.0000 - precision_11: 0.9975 - recall_11: 0.9971 - true_positives_11: 2393.0000 - true_negatives_11: 4794.0000 - false_positives_11: 6.0000 - false_negatives_11: 7.0000 - val_loss: 0.2437 - val_categorical_accuracy: 0.9333 - val_auc_11: 0.9852 - val_precision_11: 0.9331 - val_recall_11: 0.9300 - val_true_positives_11: 279.0000 - val_true_negatives_11: 580.0000 - val_false_positives_11: 20.0000 - val_false_negatives_11: 21.0000 - lr: 1.2500e-05
# Total time for trainning and validation: 2.22 (min) or 0.04 (hr)
#
#
#
#
#  +++ Testing +++
#
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1363 - categorical_accuracy: 0.9567 - auc_11: 0.9896 - precision_11: 0.9567 - recall_11: 0.9567 - true_positives_11: 287.0000 - true_negatives_11: 587.0000 - false_positives_11: 13.0000 - false_negatives_11: 13.0000
#
#
# 3/3 [==============================] - 0s 74ms/step
# 3/3 [==============================] - 0s 66ms/step
