# %% [markdown]
# #**CNN Keras Sequential for Cut images**

# %% [markdown]
# ##Drive preapare

# %% [markdown]
# #####Common Labraries

# %%
is_local = False

if not is_local:
  from google.colab import drive
  drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import os
import shutil
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, AlphaDropout

print(tf.__version__)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 2.14.0

# %% [markdown]
# #####Create sheet to save data history

# %%
if is_local:
  root_drive ='E:\\Drive\\Poscomp2023\\CutLeaves\\cutleaves-final-augmentation\\original-size\\' #local images original_augmentation_1000each
  split = '\\'
else:
  root_drive = '/content/drive/MyDrive/Poscomp2023/CutLeaves/cutleaves-final-augmentation/original-size/' #remote drive
  split = '/'
dst_path = root_drive + 'history/'

def save_df_history(df_history, optmizer_name, modelid):
  file_name = f'History-{modelid}-Keras-CNN-{optmizer_name}.xlsx'
  with pd.ExcelWriter(dst_path + file_name) as writer:
    df_history.to_excel(writer, sheet_name='sheet1')

def print_df_history(df_history):
  print(df_history)

# %% [markdown]
# ##Get images

# %% [markdown]
# #####Separate image

# %%
width = 300
height = 300


my_class_names = ['health', 'miner', 'rust']

def keras_preprocessing_image_dataset_from_directory(root, step, my_shuffle, my_batch_size):
  if os.path.exists(root+step+'.ipynb_checkpoints'):
    shutil.rmtree(root+step+'.ipynb_checkpoints')
  return tf.keras.preprocessing.image_dataset_from_directory(
            directory = root + step,
            labels = 'inferred', #labels criadas baseadas em subpastas
            label_mode = 'categorical', # mias de duas saíds possíves
            batch_size = my_batch_size,
            image_size = (width, height), #redimensiona imagem para valores de width e height
            shuffle = my_shuffle,  #define se imagens serão embaralhadas nos batch
            #class_names = my_class_names,  # Replace class names
            seed=1, #Allow always the same shuffle (default random)
            #interpolation =  =&quot;bilinear&quot;,#  bilinear, nearest, bicubic, area, lanczos3, lanczos5, gaussian, mitchellcubic.
            #crop_to_aspect_ratio = False
          )


def get_batch_size(train):
  train_iterator = train.as_numpy_iterator()
  for image, label in train_iterator:
    return image.shape[0]


print('++ Data about loaded dataset ++')
#Batch_size = 32
print('\nDataset batach_size=32')
train_32 = keras_preprocessing_image_dataset_from_directory(root_drive, f'train{split}', True, 32)
valid_32  = keras_preprocessing_image_dataset_from_directory(root_drive, f'valid{split}', False, 32)
test_32 = keras_preprocessing_image_dataset_from_directory(root_drive, f'test{split}', False, 32)
print(f"Load images batch_size={get_batch_size(train_32)}")

print(f'Classes names: {train_32.class_names}')

#Batch_size = 64
print('\nDataset batach_size=64')
train_64 = keras_preprocessing_image_dataset_from_directory(root_drive, f'train{split}', True, 64)
valid_64  = keras_preprocessing_image_dataset_from_directory(root_drive,  f'valid{split}', False, 64)
test_64 = keras_preprocessing_image_dataset_from_directory(root_drive, f'test{split}', False, 64)
print(f"Load images batch_size={get_batch_size(train_64)}")
print(f'Classes names: {train_64.class_names}')

#Batch_size = 128
print('\nDataset batach_size=128')
train_128 = keras_preprocessing_image_dataset_from_directory(root_drive, f'train{split}', True, 128)
valid_128  = keras_preprocessing_image_dataset_from_directory(root_drive,  f'valid{split}', False, 128)
test_128 = keras_preprocessing_image_dataset_from_directory(root_drive, f'test{split}', False, 128)
print(f"Load images batch_size={get_batch_size(train_128)}")
print(f'Classes names: {train_128.class_names}')
# Out:
# ++ Data about loaded dataset ++
#
# Dataset batach_size=32
# Found 2400 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.
# Load images batch_size=32
# Classes names: ['health', 'miner', 'rust']
#
# Dataset batach_size=64
# Found 2400 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.
# Load images batch_size=64
# Classes names: ['health', 'miner', 'rust']
#
# Dataset batach_size=128
# Found 2400 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.
# Load images batch_size=128
# Classes names: ['health', 'miner', 'rust']

# %% [markdown]
# #####View classes images

# %% [markdown]
# Get images and labels

# %%
def convert_label_to_class_name(label):
  id = np.where(sample_label == 1.0)[0][0]
  current_class_name = my_class_names[id]
  return current_class_name

train_32_iterator = train_32.as_numpy_iterator()
for img, label in train_32_iterator:
    break

class_index = 3
sample_image = img[class_index]
sample_label = label[class_index]
print(f'Image color min-max: ' + '[{:.2f}'.format(sample_image.min()) + '-'+ '{:.2f}'.format(sample_image.max()) + ']')
print(f'Label: {sample_label}')
class_name = convert_label_to_class_name(label)
plt.imshow(sample_image/255.0) #inshow plot image only in format color [0,1]
plt.title(f'Sample Image | class {class_name}')
plt.axis('off')
plt.show()
cv2.destroyAllWindows();
# Out:
# Image color min-max: [0.00-185.17]
# Label: [0. 0. 1.]

# %%
from IPython.core.interactiveshell import validate
#def extract_images_and_labels(images, labels):
#    return images, labels

# Apply the function to each batch of data
#train_dataset = train.map(extract_images_and_labels)
# Iterate over the batches to extract x and y
img_channel = None
print('\nTranning image shape:')
for x, y in train_32:
    print('Batch of images:', x.shape)
    _, _, _, img_channel = x.shape
    print('Batch of labels:', y.shape)
    break

print('\nValidation image shape:')
for x, y in valid_32:
    print('Batch of images:', x.shape)
    print('Batch of labels:', y.shape)
    break

print('\nTesting image shape:')
for x, y in test_32:
    print('Batch of images:', x.shape)
    print('Batch of labels:', y.shape)
    break

print(f'\nImages channel: {img_channel}')

#batch_img_train = 32
#batch_img_train, _ = next(train)
#batch_img_valid, _ = next(valid)
#batch_img_test, _ = next(test)
#print(f"Batch of images shape - train: {batch_img_train.shape}, valid: {batch_img_valid.shape}, test: {batch_img_test.shape} ")
num_classes = len(train_32.class_names)
num_classes
# Out:
# Tranning image shape:
# Batch of images: (32, 300, 300, 3)
# Batch of labels: (32, 3)
#
# Validation image shape:
# Batch of images: (32, 300, 300, 3)
# Batch of labels: (32, 3)
#
# Testing image shape:
# Batch of images: (32, 300, 300, 3)
# Batch of labels: (32, 3)
#
# Images channel: 3
# 3

# %% [markdown]
# ##Model

# %% [markdown]
# #####Model VGG16

# %%
from keras.applications import VGG16
from keras.models import Model
from keras.layers import Dense, Flatten

def model_vgg16():
  # Load the VGG16 model, excluding the top dense layers
  base_vgg16 = VGG16(weights='imagenet', include_top=False, input_shape=(width, height, img_channel))

  # Freeze the layers of the base model (optional but recommended if using pre-trained weights)
  for layer in base_vgg16.layers:
      layer.trainable = False

  # Add custom classification layers
  x = Flatten()(base_vgg16.output)
  x = Dense(512, activation='selu', kernel_initializer='lecun_normal')(x)
  predictions = Dense(3, activation='softmax')(x)

  vgg16_model = Model(inputs=base_vgg16.input, outputs=predictions)
  return vgg16_model,'vgg16'

# %% [markdown]
# #####Compile Model Sequential

# %%
def compile_model(model, optimizer):
  model.compile(    optimizer=optimizer,
                    loss='categorical_crossentropy', # para mais de duas classes e para penalizar o modelo quando há erro
                    metrics=[ #tf.keras.metrics.Accuracy(),
                              tf.keras.metrics.categorical_accuracy,
                              tf.keras.metrics.AUC(
                                                    num_thresholds = 200,
                                                    curve = 'ROC',
                                                    summation_method = 'interpolation',
                                                    name = None,
                                                    dtype = None,
                                                    thresholds = None,
                                                    multi_label = True,
                                                    num_labels = None,
                                                    label_weights = None,
                                                    from_logits = False
                                                  ),
                              tf.keras.metrics.Precision(thresholds=None, top_k=None, class_id=None, name=None, dtype=None), #Computes the precision of the predictions with respect to the labels.
                              tf.keras.metrics.Recall(thresholds=None, top_k=None, class_id=None, name=None, dtype=None),
                              tf.keras.metrics.TruePositives(thresholds=None, name=None, dtype=None),
                              tf.keras.metrics.TrueNegatives(thresholds=None, name=None, dtype=None),
                              tf.keras.metrics.FalsePositives(thresholds=None, name=None, dtype=None),
                              tf.keras.metrics.FalseNegatives(thresholds=None, name=None, dtype=None)
                            ]
                )
  return model

# %% [markdown]
# ##Train

# %% [markdown]
# #####Show end date

# %%
def calculate_total_time_min(time_start):
  time_end = time()
  time_train_seg = time_end - time_start
  time_train_min = round(time_train_seg/60, 2)
  return  time_train_min

# %% [markdown]
# #####Save History

# %%
import pickle

def save_model(model, path_dst, model_filename):
  model.save(path_dst  + model_filename)


def save_history(history, path_dst, history_filename):
  ##Save history
  with open(path_dst  + history_filename, 'wb') as f:
      pickle.dump(history.history, f)

# %% [markdown]
# #####Show Loss plot

# %%
def show_history_train(history):
  # Plot training & validation loss values
  plt.figure(figsize=(10, 6))
  plt.plot(history.history['loss'], label='Erro de treino')
  plt.plot(history.history['val_loss'], label='Erro de validação')
  plt.title('Erro de treino e validação baseado em iterações')
  plt.xlabel('Iterações')
  plt.ylabel('Erro')
  plt.legend()
  plt.show()

# %% [markdown]
# #####Run train

# %%
from matplotlib import pyplot as plt
from time import time
from tensorflow.keras.callbacks import LearningRateScheduler, LambdaCallback


initial_learning_rate = 0.0001

def step_decay(epoch):
    initial_lrate = initial_learning_rate
    drop = 0.5
    epochs_drop = 7
    lrate = initial_lrate * (drop ** (epoch // epochs_drop))
    return lrate

def run_train(model, epochs, train, valid):
  early_stopping_patience = 10
  early_stopping = keras.callbacks.EarlyStopping(
      monitor="val_loss", patience=early_stopping_patience, restore_best_weights=True
  )
  lrate_callback = LearningRateScheduler(step_decay)
  # Create a LambdaCallback to print the learning rate at the end of each epoch
  print_lrate = LambdaCallback(on_epoch_end=lambda epoch, logs: print(f"\nLearning Rate at end of epoch {epoch}: {model.optimizer.learning_rate.numpy()}"))
  history = model.fit(
                        train,
                        #steps_per_epoch=train.n // batch_size,
                        epochs=epochs,
                        #batch_size=batch_size,
                        validation_data=valid,
                        callbacks=[early_stopping, lrate_callback, print_lrate],
                        verbose=1,
                        #validation_steps=valid.n // batch_size
                      )
  return history

def call_train(model, train, valid, epochs, batch_size, model_filename, history_filename):
  time_start = time()
  history_train = run_train(model, epochs, train, valid)
  time_train_min = calculate_total_time_min(time_start)
  print('\n')
  show_history_train(history_train)
  print('\n')
  save_model(model, dst_path, model_filename)
  save_history(history_train, dst_path, history_filename)
  return time_train_min

# %% [markdown]
# ##Test

# %% [markdown]
# #####Get Test Labels and predicitions

# %%
def get_true_and_predicted_labels(model, test_data):
  predictions = model.predict(test_data)
  predicted_labels = np.argmax(predictions, axis=1)
  #print(predictions)
  true_labels = []
  # Iterate through the test_data dataset to extract true labels
  for images, labels in test_data:
      true_labels.extend(np.argmax(labels, axis=1))
  # Convert the list of true labels to a NumPy array
  true_labels = np.array(true_labels)

  n_classes = len(np.unique(true_labels))
  return true_labels, predicted_labels, predictions, n_classes

# %% [markdown]
# #####ROC plot

# %%
from sklearn.metrics import roc_curve, auc
def plot_roc(model, test_data):
  fpr = {}
  tpr = {}
  roc_auc = {}

  true_labels, predicted_labels, predictions, n_classes = get_true_and_predicted_labels(model, test_data)
  # Compute ROC curve and ROC area for each class
  for i in range(n_classes):
      fpr[i], tpr[i], _ = roc_curve((true_labels == i).astype(int), predictions[:, i])
      roc_auc[i] = auc(fpr[i], tpr[i])

  # Plot ROC curves
  plt.figure(figsize=(8, 6))
  for i in range(n_classes):
      plt.plot(fpr[i], tpr[i], lw=2, label=f'ROC curve (class {i}) (AUC = {roc_auc[i]:.2f})')

  # Plot random chance line
  plt.plot([0, 1], [0, 1], 'k--', lw=2)

  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('Receiver Operating Characteristic (ROC) Curve')
  plt.legend(loc='lower right')
  plt.show()

# %% [markdown]
# #####Print classes metrics

# %%
from sklearn.metrics import roc_curve, auc
def print_classes_metrics(model, test_data):
  fpr = {}
  tpr = {}
  roc_auc = {}

  true_labels, predicted_labels, predictions, n_classes = get_true_and_predicted_labels(model, test_data)
  # Compute ROC curve and ROC area for each class
  for i in range(n_classes):
      fpr[i], tpr[i], _ = roc_curve((true_labels == i).astype(int), predictions[:, i])
      roc_auc[i] = auc(fpr[i], tpr[i])
      precision[i], recall[i], _ = precision_recall_curve((true_labels == i).astype(int), predictions[:, i])
      f1_score[i] = 2 * (precision[i] * recall[i]) / (precision[i] + recall[i])

      print(f'\n\nClass {i} Metrics')

# %% [markdown]
# #####Confusion Matrix

# %%
import itertools
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix
from PIL import Image

def plot_confusion_matrix(model, test_data):
    # Use the model to predict the values from the test_images.
    test_pred_raw = model.predict(test_data)
    test_pred = np.argmax(test_pred_raw, axis=1)

    y_test = tf.concat([y for x, y in test_data], axis=0)
    test_labels = np.argmax(y_test, axis=1)

    # Calculate the confusion matrix using sklearn.metrics
    cm = confusion_matrix(y_true=test_labels, y_pred=test_pred)

    #print(cm)

    figure = plt.figure(figsize=(8, 8))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(test_data.class_names))
    plt.xticks(tick_marks, test_data.class_names, rotation=45)
    plt.yticks(tick_marks, test_data.class_names)

    # Use white text if squares are dark; otherwise black.
    threshold = cm.max() / 2.

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "white" if cm[i, j] > threshold else "black"
        plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    figure

# %% [markdown]
# #####Run test

# %%
def call_test(model, test_data):
  test_metrics = model.evaluate(test_data)
  print('\n');
  plot_roc(model, test_data)
  print('\n')
  plot_confusion_matrix(model, test_data)
  print('\n')
  return test_metrics

# %% [markdown]
# ##Main

# %% [markdown]
# ###Main code

# %%
def main(model, train, valid, test, learning_rate, batch_size, optimizer_param, optimizer, epochs, layers_config_number, momentum, df_history, modelid):
  print('\n\n======================================================================\n')
  print('+++ Trainning and Validation +++',end='\n\n')
  print(f'Epochs: {1} | Optmizer: {optimizer} | Batch size = {batch_size} | Learning rate = {learning_rate} | Momentum = {momentum}|Layers configuration: {layers_config_number} \n\n')
  compile_model(model, optimizer_param)
  filename = f'epochs{epochs}_batch{batch_size}_layers{layers_config_number}_momentum{momentum}'
  model_filename = f'{optimizer}/model_{optimizer}_{filename}'
  history_filename = f'{optimizer}/history_{optimizer}_{filename}'
  time_train_min = call_train(model, train, valid, epochs, batch_size, model_filename, history_filename)
  time_train_hr = round(time_train_min/60, 2)
  time_train_min = round(time_train_min, 2)
  print(f'\nTotal time for trainning and validation: {time_train_min} (min) or {time_train_hr} (hr) \n\n')
  print('\n\n +++ Testing +++ \n')
  test_metrics = call_test(model, test)
  loss = test_metrics[0]
  accuracy = test_metrics[1]
  auc = test_metrics[2]
  precision = test_metrics[3]
  recall = test_metrics[4]
  true_positives  = test_metrics[5]
  true_negatives = test_metrics[6]
  false_positives = test_metrics[7]
  false_negatives = test_metrics[8]
  list = [epochs, optimizer, batch_size, learning_rate , momentum, layers_config_number, time_train_min, time_train_hr,  loss, accuracy, auc, precision, recall, true_positives, true_negatives, false_positives, false_negatives, model_filename, history_filename]
  df_history.loc[len(df_history)] = list
  save_df_history(df_history, optimizer, modelid)
  del list, epochs, optimizer, batch_size, learning_rate, layers_config_number, time_train_min, time_train_hr,  loss, accuracy, auc, precision, recall, true_positives, true_negatives, false_positives, false_negatives, model_filename, history_filename, filename

# %% [markdown]
# ###Common values

# %%
epochs = 60
dataset_batch_size_list = ((train_32, valid_32, test_32), (train_64, valid_64, test_64), (train_128, valid_128, test_128))
learning_rate_list = (0.01, 0.001, 0.0001, 0.00001)
momentum_list = (0, 0.9, 0.99)

# %% [markdown]
# ###Optimizer = 'adam'

# %% [markdown]
# ####Model VGG16

# %%
#Store history to insert to sheet
df_history_adam = pd.DataFrame(columns=['Epochs', 'Optmizer', 'Batch_size', 'Learning_rate', 'Momentum','Layers_config', 'Training_time(min)', 'Training_time(hr)' , 'Loss', 'Accuracy', 'Auc', 'Precision', 'Recall', 'True_positives', 'True_negatives', 'False_positives', 'False_negatives','Model_filename' ,'History_filename'])
def call_adam_model_xception():
  optimizer='adam '
  model_adam_print, modelid = model_vgg16()
  print(f'\nUsed Model {modelid}:\n')
  model_adam_print.summary()
  print('\n')
  for dataset_batch_size in dataset_batch_size_list:
    train = dataset_batch_size[0]
    valid = dataset_batch_size[1]
    test = dataset_batch_size[2]
    batch_size = get_batch_size(train)
    model_adam, layers_config_adam = model_vgg16()
    optimizer_param = keras.optimizers.Adam(learning_rate=initial_learning_rate)
    main(model=model_adam, train=train, valid=valid, test=test, learning_rate=initial_learning_rate, batch_size=batch_size, optimizer_param=optimizer_param, optimizer=optimizer, epochs=epochs, layers_config_number=layers_config_adam, momentum='default', df_history=df_history_adam, modelid=modelid)
    del model_adam
call_adam_model_xception()
# Out:
# Used Model vgg16:
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 300, 300, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 300, 300, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 150, 150, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 150, 150, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 150, 150, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 75, 75, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 75, 75, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 75, 75, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 75, 75, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 37, 37, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 37, 37, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 37, 37, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 37, 37, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 18, 18, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 512)               21234176
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 35950403 (137.14 MB)
# Trainable params: 21235715 (81.01 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
#
#
#
#
# ======================================================================
#
# +++ Trainning and Validation +++
#
# Epochs: 1 | Optmizer: adam  | Batch size = 32 | Learning rate = 0.0001 | Momentum = default|Layers configuration: vgg16
#
#
# Epoch 1/60
# 75/75 [==============================] - ETA: 0s - loss: 1.5169 - categorical_accuracy: 0.8746 - auc: 0.9305 - precision: 0.8749 - recall: 0.8742 - true_positives: 2098.0000 - true_negatives: 4500.0000 - false_positives: 300.0000 - false_negatives: 302.0000
# Learning Rate at end of epoch 0: 9.999999747378752e-05
# 75/75 [==============================] - 22s 204ms/step - loss: 1.5169 - categorical_accuracy: 0.8746 - auc: 0.9305 - precision: 0.8749 - recall: 0.8742 - true_positives: 2098.0000 - true_negatives: 4500.0000 - false_positives: 300.0000 - false_negatives: 302.0000 - val_loss: 0.1446 - val_categorical_accuracy: 0.9600 - val_auc: 0.9905 - val_precision: 0.9600 - val_recall: 0.9600 - val_true_positives: 288.0000 - val_true_negatives: 588.0000 - val_false_positives: 12.0000 - val_false_negatives: 12.0000 - lr: 1.0000e-04
# Epoch 2/60
# 75/75 [==============================] - ETA: 0s - loss: 0.0413 - categorical_accuracy: 0.9883 - auc: 0.9995 - precision: 0.9883 - recall: 0.9883 - true_positives: 2372.0000 - true_negatives: 4772.0000 - false_positives: 28.0000 - false_negatives: 28.0000
# Learning Rate at end of epoch 1: 9.999999747378752e-05
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0413 - categorical_accuracy: 0.9883 - auc: 0.9995 - precision: 0.9883 - recall: 0.9883 - true_positives: 2372.0000 - true_negatives: 4772.0000 - false_positives: 28.0000 - false_negatives: 28.0000 - val_loss: 0.1074 - val_categorical_accuracy: 0.9633 - val_auc: 0.9959 - val_precision: 0.9666 - val_recall: 0.9633 - val_true_positives: 289.0000 - val_true_negatives: 590.0000 - val_false_positives: 10.0000 - val_false_negatives: 11.0000 - lr: 1.0000e-04
# Epoch 3/60
# 75/75 [==============================] - ETA: 0s - loss: 0.0065 - categorical_accuracy: 0.9983 - auc: 1.0000 - precision: 0.9983 - recall: 0.9983 - true_positives: 2396.0000 - true_negatives: 4796.0000 - false_positives: 4.0000 - false_negatives: 4.0000
# Learning Rate at end of epoch 2: 9.999999747378752e-05
# 75/75 [==============================] - 12s 155ms/step - loss: 0.0065 - categorical_accuracy: 0.9983 - auc: 1.0000 - precision: 0.9983 - recall: 0.9983 - true_positives: 2396.0000 - true_negatives: 4796.0000 - false_positives: 4.0000 - false_negatives: 4.0000 - val_loss: 0.1311 - val_categorical_accuracy: 0.9733 - val_auc: 0.9917 - val_precision: 0.9733 - val_recall: 0.9733 - val_true_positives: 292.0000 - val_true_negatives: 592.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - lr: 1.0000e-04
# Epoch 4/60
# 75/75 [==============================] - ETA: 0s - loss: 6.6106e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Learning Rate at end of epoch 3: 9.999999747378752e-05
# 75/75 [==============================] - 16s 203ms/step - loss: 6.6106e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 0.0938 - val_categorical_accuracy: 0.9733 - val_auc: 0.9940 - val_precision: 0.9733 - val_recall: 0.9733 - val_true_positives: 292.0000 - val_true_negatives: 592.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - lr: 1.0000e-04
# Epoch 5/60
# 75/75 [==============================] - ETA: 0s - loss: 9.7619e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Learning Rate at end of epoch 4: 9.999999747378752e-05
# 75/75 [==============================] - 11s 146ms/step - loss: 9.7619e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 0.0943 - val_categorical_accuracy: 0.9733 - val_auc: 0.9964 - val_precision: 0.9733 - val_recall: 0.9733 - val_true_positives: 292.0000 - val_true_negatives: 592.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - lr: 1.0000e-04
# Epoch 6/60
# 75/75 [==============================] - ETA: 0s - loss: 7.7104e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Learning Rate at end of epoch 5: 9.999999747378752e-05
# 75/75 [==============================] - 12s 153ms/step - loss: 7.7104e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 0.0944 - val_categorical_accuracy: 0.9767 - val_auc: 0.9941 - val_precision: 0.9767 - val_recall: 0.9767 - val_true_positives: 293.0000 - val_true_negatives: 593.0000 - val_false_positives: 7.0000 - val_false_negatives: 7.0000 - lr: 1.0000e-04
# Epoch 7/60
# 75/75 [==============================] - ETA: 0s - loss: 6.4964e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Learning Rate at end of epoch 6: 9.999999747378752e-05
# 75/75 [==============================] - 13s 172ms/step - loss: 6.4964e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 0.0943 - val_categorical_accuracy: 0.9767 - val_auc: 0.9940 - val_precision: 0.9767 - val_recall: 0.9767 - val_true_positives: 293.0000 - val_true_negatives: 593.0000 - val_false_positives: 7.0000 - val_false_negatives: 7.0000 - lr: 1.0000e-04
# Epoch 8/60
# 75/75 [==============================] - ETA: 0s - loss: 5.6479e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Learning Rate at end of epoch 7: 4.999999873689376e-05
# 75/75 [==============================] - 11s 143ms/step - loss: 5.6479e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 0.0942 - val_categorical_accuracy: 0.9767 - val_auc: 0.9940 - val_precision: 0.9767 - val_recall: 0.9767 - val_true_positives: 293.0000 - val_true_negatives: 593.0000 - val_false_positives: 7.0000 - val_false_negatives: 7.0000 - lr: 5.0000e-05
# Epoch 9/60
# 75/75 [==============================] - ETA: 0s - loss: 5.2871e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Learning Rate at end of epoch 8: 4.999999873689376e-05
# 75/75 [==============================] - 10s 137ms/step - loss: 5.2871e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 0.0941 - val_categorical_accuracy: 0.9767 - val_auc: 0.9940 - val_precision: 0.9767 - val_recall: 0.9767 - val_true_positives: 293.0000 - val_true_negatives: 593.0000 - val_false_positives: 7.0000 - val_false_negatives: 7.0000 - lr: 5.0000e-05
# Epoch 10/60
# 75/75 [==============================] - ETA: 0s - loss: 4.9364e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Learning Rate at end of epoch 9: 4.999999873689376e-05
# 75/75 [==============================] - 15s 203ms/step - loss: 4.9364e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 0.0941 - val_categorical_accuracy: 0.9767 - val_auc: 0.9940 - val_precision: 0.9767 - val_recall: 0.9767 - val_true_positives: 293.0000 - val_true_negatives: 593.0000 - val_false_positives: 7.0000 - val_false_negatives: 7.0000 - lr: 5.0000e-05
# Epoch 11/60
# 75/75 [==============================] - ETA: 0s - loss: 4.6007e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Learning Rate at end of epoch 10: 4.999999873689376e-05
# 75/75 [==============================] - 14s 180ms/step - loss: 4.6007e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 0.0941 - val_categorical_accuracy: 0.9767 - val_auc: 0.9941 - val_precision: 0.9767 - val_recall: 0.9767 - val_true_positives: 293.0000 - val_true_negatives: 593.0000 - val_false_positives: 7.0000 - val_false_negatives: 7.0000 - lr: 5.0000e-05
# Epoch 12/60
# 75/75 [==============================] - ETA: 0s - loss: 4.3079e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Learning Rate at end of epoch 11: 4.999999873689376e-05
# 75/75 [==============================] - 14s 180ms/step - loss: 4.3079e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 0.0939 - val_categorical_accuracy: 0.9767 - val_auc: 0.9940 - val_precision: 0.9767 - val_recall: 0.9767 - val_true_positives: 293.0000 - val_true_negatives: 593.0000 - val_false_positives: 7.0000 - val_false_negatives: 7.0000 - lr: 5.0000e-05
# Epoch 13/60
# 75/75 [==============================] - ETA: 0s - loss: 4.0405e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Learning Rate at end of epoch 12: 4.999999873689376e-05
# 75/75 [==============================] - 13s 167ms/step - loss: 4.0405e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 0.0939 - val_categorical_accuracy: 0.9767 - val_auc: 0.9940 - val_precision: 0.9767 - val_recall: 0.9767 - val_true_positives: 293.0000 - val_true_negatives: 593.0000 - val_false_positives: 7.0000 - val_false_negatives: 7.0000 - lr: 5.0000e-05
# Epoch 14/60
# 75/75 [==============================] - ETA: 0s - loss: 3.7864e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Learning Rate at end of epoch 13: 4.999999873689376e-05
# 75/75 [==============================] - 13s 169ms/step - loss: 3.7864e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - true_positives: 2400.0000 - true_negatives: 4800.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - val_loss: 0.0939 - val_categorical_accuracy: 0.9767 - val_auc: 0.9940 - val_precision: 0.9767 - val_recall: 0.9767 - val_true_positives: 293.0000 - val_true_negatives: 593.0000 - val_false_positives: 7.0000 - val_false_negatives: 7.0000 - lr: 5.0000e-05
# Total time for trainning and validation: 3.17 (min) or 0.05 (hr)
#
#
#
#
#  +++ Testing +++
#
# 10/10 [==============================] - 1s 100ms/step - loss: 0.1047 - categorical_accuracy: 0.9700 - auc: 0.9938 - precision: 0.9700 - recall: 0.9700 - true_positives: 291.0000 - true_negatives: 591.0000 - false_positives: 9.0000 - false_negatives: 9.0000
#
#
# 10/10 [==============================] - 2s 146ms/step
# 10/10 [==============================] - 2s 182ms/step
#
#
#
#
# ======================================================================
#
# +++ Trainning and Validation +++
#
# Epochs: 1 | Optmizer: adam  | Batch size = 64 | Learning rate = 0.0001 | Momentum = default|Layers configuration: vgg16
#
#
# Epoch 1/60
# 38/38 [==============================] - ETA: 0s - loss: 1.6018 - categorical_accuracy: 0.8512 - auc_1: 0.9199 - precision_1: 0.8519 - recall_1: 0.8508 - true_positives_1: 2042.0000 - true_negatives_1: 4445.0000 - false_positives_1: 355.0000 - false_negatives_1: 358.0000
# Learning Rate at end of epoch 0: 9.999999747378752e-05
# 38/38 [==============================] - 20s 373ms/step - loss: 1.6018 - categorical_accuracy: 0.8512 - auc_1: 0.9199 - precision_1: 0.8519 - recall_1: 0.8508 - true_positives_1: 2042.0000 - true_negatives_1: 4445.0000 - false_positives_1: 355.0000 - false_negatives_1: 358.0000 - val_loss: 0.4147 - val_categorical_accuracy: 0.9400 - val_auc_1: 0.9750 - val_precision_1: 0.9400 - val_recall_1: 0.9400 - val_true_positives_1: 282.0000 - val_true_negatives_1: 582.0000 - val_false_positives_1: 18.0000 - val_false_negatives_1: 18.0000 - lr: 1.0000e-04
# Epoch 2/60
# 38/38 [==============================] - ETA: 0s - loss: 0.0503 - categorical_accuracy: 0.9858 - auc_1: 0.9979 - precision_1: 0.9858 - recall_1: 0.9858 - true_positives_1: 2366.0000 - true_negatives_1: 4766.0000 - false_positives_1: 34.0000 - false_negatives_1: 34.0000
# Learning Rate at end of epoch 1: 9.999999747378752e-05
# 38/38 [==============================] - 11s 282ms/step - loss: 0.0503 - categorical_accuracy: 0.9858 - auc_1: 0.9979 - precision_1: 0.9858 - recall_1: 0.9858 - true_positives_1: 2366.0000 - true_negatives_1: 4766.0000 - false_positives_1: 34.0000 - false_negatives_1: 34.0000 - val_loss: 0.1896 - val_categorical_accuracy: 0.9533 - val_auc_1: 0.9901 - val_precision_1: 0.9533 - val_recall_1: 0.9533 - val_true_positives_1: 286.0000 - val_true_negatives_1: 586.0000 - val_false_positives_1: 14.0000 - val_false_negatives_1: 14.0000 - lr: 1.0000e-04
# Epoch 3/60
# 38/38 [==============================] - ETA: 0s - loss: 0.0137 - categorical_accuracy: 0.9975 - auc_1: 0.9996 - precision_1: 0.9975 - recall_1: 0.9975 - true_positives_1: 2394.0000 - true_negatives_1: 4794.0000 - false_positives_1: 6.0000 - false_negatives_1: 6.0000
# Learning Rate at end of epoch 2: 9.999999747378752e-05
# 38/38 [==============================] - 12s 304ms/step - loss: 0.0137 - categorical_accuracy: 0.9975 - auc_1: 0.9996 - precision_1: 0.9975 - recall_1: 0.9975 - true_positives_1: 2394.0000 - true_negatives_1: 4794.0000 - false_positives_1: 6.0000 - false_negatives_1: 6.0000 - val_loss: 0.2115 - val_categorical_accuracy: 0.9667 - val_auc_1: 0.9850 - val_precision_1: 0.9666 - val_recall_1: 0.9633 - val_true_positives_1: 289.0000 - val_true_negatives_1: 590.0000 - val_false_positives_1: 10.0000 - val_false_negatives_1: 11.0000 - lr: 1.0000e-04
# Epoch 4/60
# 38/38 [==============================] - ETA: 0s - loss: 0.0063 - categorical_accuracy: 0.9967 - auc_1: 1.0000 - precision_1: 0.9967 - recall_1: 0.9967 - true_positives_1: 2392.0000 - true_negatives_1: 4792.0000 - false_positives_1: 8.0000 - false_negatives_1: 8.0000
# Learning Rate at end of epoch 3: 9.999999747378752e-05
# 38/38 [==============================] - 11s 288ms/step - loss: 0.0063 - categorical_accuracy: 0.9967 - auc_1: 1.0000 - precision_1: 0.9967 - recall_1: 0.9967 - true_positives_1: 2392.0000 - true_negatives_1: 4792.0000 - false_positives_1: 8.0000 - false_negatives_1: 8.0000 - val_loss: 0.2224 - val_categorical_accuracy: 0.9733 - val_auc_1: 0.9868 - val_precision_1: 0.9732 - val_recall_1: 0.9700 - val_true_positives_1: 291.0000 - val_true_negatives_1: 592.0000 - val_false_positives_1: 8.0000 - val_false_negatives_1: 9.0000 - lr: 1.0000e-04
# Epoch 5/60
# 38/38 [==============================] - ETA: 0s - loss: 3.3439e-04 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00
# Learning Rate at end of epoch 4: 9.999999747378752e-05
# 38/38 [==============================] - 11s 272ms/step - loss: 3.3439e-04 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00 - val_loss: 0.1810 - val_categorical_accuracy: 0.9667 - val_auc_1: 0.9867 - val_precision_1: 0.9667 - val_recall_1: 0.9667 - val_true_positives_1: 290.0000 - val_true_negatives_1: 590.0000 - val_false_positives_1: 10.0000 - val_false_negatives_1: 10.0000 - lr: 1.0000e-04
# Epoch 6/60
# 38/38 [==============================] - ETA: 0s - loss: 6.7328e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00
# Learning Rate at end of epoch 5: 9.999999747378752e-05
# 38/38 [==============================] - 11s 278ms/step - loss: 6.7328e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00 - val_loss: 0.1852 - val_categorical_accuracy: 0.9667 - val_auc_1: 0.9867 - val_precision_1: 0.9667 - val_recall_1: 0.9667 - val_true_positives_1: 290.0000 - val_true_negatives_1: 590.0000 - val_false_positives_1: 10.0000 - val_false_negatives_1: 10.0000 - lr: 1.0000e-04
# Epoch 7/60
# 38/38 [==============================] - ETA: 0s - loss: 4.4102e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00
# Learning Rate at end of epoch 6: 9.999999747378752e-05
# 38/38 [==============================] - 9s 241ms/step - loss: 4.4102e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00 - val_loss: 0.1882 - val_categorical_accuracy: 0.9667 - val_auc_1: 0.9867 - val_precision_1: 0.9667 - val_recall_1: 0.9667 - val_true_positives_1: 290.0000 - val_true_negatives_1: 590.0000 - val_false_positives_1: 10.0000 - val_false_negatives_1: 10.0000 - lr: 1.0000e-04
# Epoch 8/60
# 38/38 [==============================] - ETA: 0s - loss: 3.6641e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00
# Learning Rate at end of epoch 7: 4.999999873689376e-05
# 38/38 [==============================] - 11s 276ms/step - loss: 3.6641e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00 - val_loss: 0.1894 - val_categorical_accuracy: 0.9700 - val_auc_1: 0.9867 - val_precision_1: 0.9700 - val_recall_1: 0.9700 - val_true_positives_1: 291.0000 - val_true_negatives_1: 591.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 9.0000 - lr: 5.0000e-05
# Epoch 9/60
# 38/38 [==============================] - ETA: 0s - loss: 3.3460e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00
# Learning Rate at end of epoch 8: 4.999999873689376e-05
# 38/38 [==============================] - 10s 249ms/step - loss: 3.3460e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00 - val_loss: 0.1904 - val_categorical_accuracy: 0.9700 - val_auc_1: 0.9867 - val_precision_1: 0.9700 - val_recall_1: 0.9700 - val_true_positives_1: 291.0000 - val_true_negatives_1: 591.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 9.0000 - lr: 5.0000e-05
# Epoch 10/60
# 38/38 [==============================] - ETA: 0s - loss: 3.0839e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00
# Learning Rate at end of epoch 9: 4.999999873689376e-05
# 38/38 [==============================] - 10s 244ms/step - loss: 3.0839e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00 - val_loss: 0.1911 - val_categorical_accuracy: 0.9700 - val_auc_1: 0.9867 - val_precision_1: 0.9700 - val_recall_1: 0.9700 - val_true_positives_1: 291.0000 - val_true_negatives_1: 591.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 9.0000 - lr: 5.0000e-05
# Epoch 11/60
# 38/38 [==============================] - ETA: 0s - loss: 2.8657e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00
# Learning Rate at end of epoch 10: 4.999999873689376e-05
# 38/38 [==============================] - 14s 352ms/step - loss: 2.8657e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00 - val_loss: 0.1918 - val_categorical_accuracy: 0.9700 - val_auc_1: 0.9867 - val_precision_1: 0.9700 - val_recall_1: 0.9700 - val_true_positives_1: 291.0000 - val_true_negatives_1: 591.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 9.0000 - lr: 5.0000e-05
# Epoch 12/60
# 38/38 [==============================] - ETA: 0s - loss: 2.6783e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00
# Learning Rate at end of epoch 11: 4.999999873689376e-05
# 38/38 [==============================] - 9s 229ms/step - loss: 2.6783e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00 - val_loss: 0.1927 - val_categorical_accuracy: 0.9700 - val_auc_1: 0.9867 - val_precision_1: 0.9700 - val_recall_1: 0.9700 - val_true_positives_1: 291.0000 - val_true_negatives_1: 591.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 9.0000 - lr: 5.0000e-05
# Epoch 13/60
# 38/38 [==============================] - ETA: 0s - loss: 2.5135e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00
# Learning Rate at end of epoch 12: 4.999999873689376e-05
# 38/38 [==============================] - 12s 310ms/step - loss: 2.5135e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00 - val_loss: 0.1932 - val_categorical_accuracy: 0.9700 - val_auc_1: 0.9867 - val_precision_1: 0.9700 - val_recall_1: 0.9700 - val_true_positives_1: 291.0000 - val_true_negatives_1: 591.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 9.0000 - lr: 5.0000e-05
# Epoch 14/60
# 38/38 [==============================] - ETA: 0s - loss: 2.3821e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00
# Learning Rate at end of epoch 13: 4.999999873689376e-05
# 38/38 [==============================] - 9s 217ms/step - loss: 2.3821e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00 - val_loss: 0.1938 - val_categorical_accuracy: 0.9700 - val_auc_1: 0.9867 - val_precision_1: 0.9700 - val_recall_1: 0.9700 - val_true_positives_1: 291.0000 - val_true_negatives_1: 591.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 9.0000 - lr: 5.0000e-05
# Epoch 15/60
# 38/38 [==============================] - ETA: 0s - loss: 2.2689e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00
# Learning Rate at end of epoch 14: 2.499999936844688e-05
# 38/38 [==============================] - 10s 253ms/step - loss: 2.2689e-05 - categorical_accuracy: 1.0000 - auc_1: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - true_positives_1: 2400.0000 - true_negatives_1: 4800.0000 - false_positives_1: 0.0000e+00 - false_negatives_1: 0.0000e+00 - val_loss: 0.1941 - val_categorical_accuracy: 0.9700 - val_auc_1: 0.9867 - val_precision_1: 0.9700 - val_recall_1: 0.9700 - val_true_positives_1: 291.0000 - val_true_negatives_1: 591.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 9.0000 - lr: 2.5000e-05
# Total time for trainning and validation: 2.85 (min) or 0.05 (hr)
#
#
#
#
#  +++ Testing +++
#
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1454 - categorical_accuracy: 0.9700 - auc_1: 0.9914 - precision_1: 0.9700 - recall_1: 0.9700 - true_positives_1: 291.0000 - true_negatives_1: 591.0000 - false_positives_1: 9.0000 - false_negatives_1: 9.0000
#
#
# 5/5 [==============================] - 2s 492ms/step
# 5/5 [==============================] - 1s 149ms/step
#
#
#
#
# ======================================================================
#
# +++ Trainning and Validation +++
#
# Epochs: 1 | Optmizer: adam  | Batch size = 128 | Learning rate = 0.0001 | Momentum = default|Layers configuration: vgg16
#
#
# Epoch 1/60
# 19/19 [==============================] - ETA: 0s - loss: 3.1580 - categorical_accuracy: 0.7721 - auc_2: 0.8671 - precision_2: 0.7750 - recall_2: 0.7721 - true_positives_2: 1853.0000 - true_negatives_2: 4262.0000 - false_positives_2: 538.0000 - false_negatives_2: 547.0000
# Learning Rate at end of epoch 0: 9.999999747378752e-05
# 19/19 [==============================] - 26s 919ms/step - loss: 3.1580 - categorical_accuracy: 0.7721 - auc_2: 0.8671 - precision_2: 0.7750 - recall_2: 0.7721 - true_positives_2: 1853.0000 - true_negatives_2: 4262.0000 - false_positives_2: 538.0000 - false_negatives_2: 547.0000 - val_loss: 0.3696 - val_categorical_accuracy: 0.9533 - val_auc_2: 0.9784 - val_precision_2: 0.9533 - val_recall_2: 0.9533 - val_true_positives_2: 286.0000 - val_true_negatives_2: 586.0000 - val_false_positives_2: 14.0000 - val_false_negatives_2: 14.0000 - lr: 1.0000e-04
# Epoch 2/60
# 19/19 [==============================] - ETA: 0s - loss: 0.2219 - categorical_accuracy: 0.9646 - auc_2: 0.9871 - precision_2: 0.9646 - recall_2: 0.9646 - true_positives_2: 2315.0000 - true_negatives_2: 4715.0000 - false_positives_2: 85.0000 - false_negatives_2: 85.0000
# Learning Rate at end of epoch 1: 9.999999747378752e-05
# 19/19 [==============================] - 9s 445ms/step - loss: 0.2219 - categorical_accuracy: 0.9646 - auc_2: 0.9871 - precision_2: 0.9646 - recall_2: 0.9646 - true_positives_2: 2315.0000 - true_negatives_2: 4715.0000 - false_positives_2: 85.0000 - false_negatives_2: 85.0000 - val_loss: 0.4214 - val_categorical_accuracy: 0.9400 - val_auc_2: 0.9772 - val_precision_2: 0.9400 - val_recall_2: 0.9400 - val_true_positives_2: 282.0000 - val_true_negatives_2: 582.0000 - val_false_positives_2: 18.0000 - val_false_negatives_2: 18.0000 - lr: 1.0000e-04
# Epoch 3/60
# 19/19 [==============================] - ETA: 0s - loss: 0.0238 - categorical_accuracy: 0.9937 - auc_2: 0.9988 - precision_2: 0.9937 - recall_2: 0.9937 - true_positives_2: 2385.0000 - true_negatives_2: 4785.0000 - false_positives_2: 15.0000 - false_negatives_2: 15.0000
# Learning Rate at end of epoch 2: 9.999999747378752e-05
# 19/19 [==============================] - 11s 545ms/step - loss: 0.0238 - categorical_accuracy: 0.9937 - auc_2: 0.9988 - precision_2: 0.9937 - recall_2: 0.9937 - true_positives_2: 2385.0000 - true_negatives_2: 4785.0000 - false_positives_2: 15.0000 - false_negatives_2: 15.0000 - val_loss: 0.2009 - val_categorical_accuracy: 0.9700 - val_auc_2: 0.9897 - val_precision_2: 0.9700 - val_recall_2: 0.9700 - val_true_positives_2: 291.0000 - val_true_negatives_2: 591.0000 - val_false_positives_2: 9.0000 - val_false_negatives_2: 9.0000 - lr: 1.0000e-04
# Epoch 4/60
# 19/19 [==============================] - ETA: 0s - loss: 7.2057e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 3: 9.999999747378752e-05
# 19/19 [==============================] - 10s 493ms/step - loss: 7.2057e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.2654 - val_categorical_accuracy: 0.9500 - val_auc_2: 0.9822 - val_precision_2: 0.9500 - val_recall_2: 0.9500 - val_true_positives_2: 285.0000 - val_true_negatives_2: 585.0000 - val_false_positives_2: 15.0000 - val_false_negatives_2: 15.0000 - lr: 1.0000e-04
# Epoch 5/60
# 19/19 [==============================] - ETA: 0s - loss: 4.9671e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 4: 9.999999747378752e-05
# 19/19 [==============================] - 8s 365ms/step - loss: 4.9671e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.2666 - val_categorical_accuracy: 0.9500 - val_auc_2: 0.9822 - val_precision_2: 0.9500 - val_recall_2: 0.9500 - val_true_positives_2: 285.0000 - val_true_negatives_2: 585.0000 - val_false_positives_2: 15.0000 - val_false_negatives_2: 15.0000 - lr: 1.0000e-04
# Epoch 6/60
# 19/19 [==============================] - ETA: 0s - loss: 1.7111e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 5: 9.999999747378752e-05
# 19/19 [==============================] - 10s 471ms/step - loss: 1.7111e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.2532 - val_categorical_accuracy: 0.9500 - val_auc_2: 0.9822 - val_precision_2: 0.9500 - val_recall_2: 0.9500 - val_true_positives_2: 285.0000 - val_true_negatives_2: 585.0000 - val_false_positives_2: 15.0000 - val_false_negatives_2: 15.0000 - lr: 1.0000e-04
# Epoch 7/60
# 19/19 [==============================] - ETA: 0s - loss: 1.3874e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 6: 9.999999747378752e-05
# 19/19 [==============================] - 10s 512ms/step - loss: 1.3874e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.2507 - val_categorical_accuracy: 0.9500 - val_auc_2: 0.9822 - val_precision_2: 0.9500 - val_recall_2: 0.9500 - val_true_positives_2: 285.0000 - val_true_negatives_2: 585.0000 - val_false_positives_2: 15.0000 - val_false_negatives_2: 15.0000 - lr: 1.0000e-04
# Epoch 8/60
# 19/19 [==============================] - ETA: 0s - loss: 1.2405e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 7: 4.999999873689376e-05
# 19/19 [==============================] - 9s 417ms/step - loss: 1.2405e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.2501 - val_categorical_accuracy: 0.9500 - val_auc_2: 0.9822 - val_precision_2: 0.9500 - val_recall_2: 0.9500 - val_true_positives_2: 285.0000 - val_true_negatives_2: 585.0000 - val_false_positives_2: 15.0000 - val_false_negatives_2: 15.0000 - lr: 5.0000e-05
# Epoch 9/60
# 19/19 [==============================] - ETA: 0s - loss: 1.1608e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 8: 4.999999873689376e-05
# 19/19 [==============================] - 10s 502ms/step - loss: 1.1608e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.2502 - val_categorical_accuracy: 0.9500 - val_auc_2: 0.9822 - val_precision_2: 0.9500 - val_recall_2: 0.9500 - val_true_positives_2: 285.0000 - val_true_negatives_2: 585.0000 - val_false_positives_2: 15.0000 - val_false_negatives_2: 15.0000 - lr: 5.0000e-05
# Epoch 10/60
# 19/19 [==============================] - ETA: 0s - loss: 1.0957e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 9: 4.999999873689376e-05
# 19/19 [==============================] - 10s 484ms/step - loss: 1.0957e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.2501 - val_categorical_accuracy: 0.9500 - val_auc_2: 0.9822 - val_precision_2: 0.9500 - val_recall_2: 0.9500 - val_true_positives_2: 285.0000 - val_true_negatives_2: 585.0000 - val_false_positives_2: 15.0000 - val_false_negatives_2: 15.0000 - lr: 5.0000e-05
# Epoch 11/60
# 19/19 [==============================] - ETA: 0s - loss: 1.0358e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 10: 4.999999873689376e-05
# 19/19 [==============================] - 10s 505ms/step - loss: 1.0358e-04 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.2494 - val_categorical_accuracy: 0.9500 - val_auc_2: 0.9846 - val_precision_2: 0.9500 - val_recall_2: 0.9500 - val_true_positives_2: 285.0000 - val_true_negatives_2: 585.0000 - val_false_positives_2: 15.0000 - val_false_negatives_2: 15.0000 - lr: 5.0000e-05
# Epoch 12/60
# 19/19 [==============================] - ETA: 0s - loss: 9.8899e-05 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 11: 4.999999873689376e-05
# 19/19 [==============================] - 10s 486ms/step - loss: 9.8899e-05 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.2497 - val_categorical_accuracy: 0.9500 - val_auc_2: 0.9846 - val_precision_2: 0.9500 - val_recall_2: 0.9500 - val_true_positives_2: 285.0000 - val_true_negatives_2: 585.0000 - val_false_positives_2: 15.0000 - val_false_negatives_2: 15.0000 - lr: 5.0000e-05
# Epoch 13/60
# 19/19 [==============================] - ETA: 0s - loss: 9.2862e-05 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 12: 4.999999873689376e-05
# 19/19 [==============================] - 10s 488ms/step - loss: 9.2862e-05 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 2400.0000 - true_negatives_2: 4800.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.2492 - val_categorical_accuracy: 0.9500 - val_auc_2: 0.9846 - val_precision_2: 0.9500 - val_recall_2: 0.9500 - val_true_positives_2: 285.0000 - val_true_negatives_2: 585.0000 - val_false_positives_2: 15.0000 - val_false_negatives_2: 15.0000 - lr: 5.0000e-05
# Total time for trainning and validation: 2.45 (min) or 0.04 (hr)
#
#
#
#
#  +++ Testing +++
#
# 3/3 [==============================] - 1s 214ms/step - loss: 0.1992 - categorical_accuracy: 0.9533 - auc_2: 0.9867 - precision_2: 0.9533 - recall_2: 0.9533 - true_positives_2: 286.0000 - true_negatives_2: 586.0000 - false_positives_2: 14.0000 - false_negatives_2: 14.0000
#
#
# 3/3 [==============================] - 1s 379ms/step
# 3/3 [==============================] - 1s 289ms/step
