# %% [markdown]
# #**CNN Keras Sequential for Whole images**

# %% [markdown]
# ##Drive preapare

# %% [markdown]
# #####Common Labraries

# %%
is_local = False

if not is_local:
  from google.colab import drive
  drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import os
import shutil
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, AlphaDropout

print(tf.__version__)
# Out:
# Mounted at /content/drive
# 2.14.0

# %% [markdown]
# #####Create sheet to save data history

# %%
if is_local:
  root_drive =r'E:\Drive\Poscomp2023\WholeLeaves\wholeleaves-final-augmentation\\' #local images
  split = '\\'
else:
  root_drive = '/content/drive/MyDrive/Poscomp2023/WholeLeaves/wholeleaves-final-augmentation/' #remote drive
  split = '/'
dst_path = root_drive + 'history/'

def save_df_history(df_history, optmizer_name,type_model):
  file_name = f'History-Sequential-Keras-CNN-{optmizer_name}.xlsx'
  with pd.ExcelWriter(dst_path + file_name) as writer:
    df_history.to_excel(writer, sheet_name='sheet1')

def print_df_history(df_history):
  print(df_history)

# %% [markdown]
# ##Get images

# %% [markdown]
# #####Separate image

# %%
width = 300
height = 300


my_class_names = ['saudavel', 'severidade1','severidade2']

def keras_preprocessing_image_dataset_from_directory(root, step, my_shuffle, my_batch_size):
  if os.path.exists(root+step+'.ipynb_checkpoints'):
    shutil.rmtree(root+step+'.ipynb_checkpoints')
  return tf.keras.preprocessing.image_dataset_from_directory(
            directory = root + step,
            labels = 'inferred', #labels criadas baseadas em subpastas
            label_mode = 'categorical', # mias de duas saíds possíves
            batch_size = my_batch_size,
            image_size = (width, height), #redimensiona imagem para valores de width e height
            shuffle = my_shuffle,  #define se imagens serão embaralhadas nos batch
            #class_names = my_class_names,  # Replace class names
            seed=1, #Allow always the same shuffle (default random)
            #interpolation =  =&quot;bilinear&quot;,#  bilinear, nearest, bicubic, area, lanczos3, lanczos5, gaussian, mitchellcubic.
            #crop_to_aspect_ratio = False
          )


def get_batch_size(train):
  train_iterator = train.as_numpy_iterator()
  for image, label in train_iterator:
    return image.shape[0]


print('++ Data about loaded dataset ++')
#Batch_size = 32
print('\nDataset batach_size=32')
train_32 = keras_preprocessing_image_dataset_from_directory(root_drive, f'train{split}', True, 32)
valid_32  = keras_preprocessing_image_dataset_from_directory(root_drive, f'valid{split}', False, 32)
test_32 = keras_preprocessing_image_dataset_from_directory(root_drive, f'test{split}', False, 32)
print(f"Load images batch_size={get_batch_size(train_32)}")

print(f'Classes names: {train_32.class_names}')

#Batch_size = 64
print('\nDataset batach_size=64')
train_64 = keras_preprocessing_image_dataset_from_directory(root_drive, f'train{split}', True, 64)
valid_64  = keras_preprocessing_image_dataset_from_directory(root_drive,  f'valid{split}', False, 64)
test_64 = keras_preprocessing_image_dataset_from_directory(root_drive, f'test{split}', False, 64)
print(f"Load images batch_size={get_batch_size(train_64)}")
print(f'Classes names: {train_64.class_names}')

#Batch_size = 128
print('\nDataset batach_size=128')
train_128 = keras_preprocessing_image_dataset_from_directory(root_drive, f'train{split}', True, 128)
valid_128  = keras_preprocessing_image_dataset_from_directory(root_drive,  f'valid{split}', False, 128)
test_128 = keras_preprocessing_image_dataset_from_directory(root_drive, f'test{split}', False, 128)
print(f"Load images batch_size={get_batch_size(train_128)}")
print(f'Classes names: {train_128.class_names}')
# Out:
# ++ Data about loaded dataset ++
#
# Dataset batach_size=32
# Found 1200 files belonging to 3 classes.
# Found 150 files belonging to 3 classes.
# Found 150 files belonging to 3 classes.
# Load images batch_size=32
# Classes names: ['health', 'severity1', 'severity2']
#
# Dataset batach_size=64
# Found 1200 files belonging to 3 classes.
# Found 150 files belonging to 3 classes.
# Found 150 files belonging to 3 classes.
# Load images batch_size=64
# Classes names: ['health', 'severity1', 'severity2']
#
# Dataset batach_size=128
# Found 1200 files belonging to 3 classes.
# Found 150 files belonging to 3 classes.
# Found 150 files belonging to 3 classes.
# Load images batch_size=128
# Classes names: ['health', 'severity1', 'severity2']

# %% [markdown]
# #####View classes images

# %% [markdown]
# Get images and labels

# %%
#def convert_label_to_class_name(label):
#  id = np.where(sample_label == 1.0)[0][0]
#  current_class_name = my_class_names[id]
#  return current_class_name
#
#train_32_iterator = train_32.as_numpy_iterator()
#for img, label in train_32_iterator:
#    break
#
#class_index = 3
#sample_image = img[class_index]
#sample_label = label[class_index]
#print(f'Image color min-max: ' + '[{:.2f}'.format(sample_image.min()) + '-'+ '{:.2f}'.format(sample_image.max()) + ']')
#print(f'Label: {sample_label}')
#class_name = convert_label_to_class_name(label)
#plt.imshow(sample_image/255.0) #inshow plot image only in format color [0,1]
#plt.title(f'Sample Image | class {class_name}')
#plt.axis('off')
#plt.show()
#cv2.destroyAllWindows();

# %%
from IPython.core.interactiveshell import validate
#def extract_images_and_labels(images, labels):
#    return images, labels

# Apply the function to each batch of data
#train_dataset = train.map(extract_images_and_labels)
# Iterate over the batches to extract x and y
img_channel = None
print('\nTranning image shape:')
for x, y in train_32:
    print('Batch of images:', x.shape)
    _, _, _, img_channel = x.shape
    print('Batch of labels:', y.shape)
    break

print('\nValidation image shape:')
for x, y in valid_32:
    print('Batch of images:', x.shape)
    print('Batch of labels:', y.shape)
    break

print('\nTesting image shape:')
for x, y in test_32:
    print('Batch of images:', x.shape)
    print('Batch of labels:', y.shape)
    break

print(f'\nImages channel: {img_channel}')

#batch_img_train = 32
#batch_img_train, _ = next(train)
#batch_img_valid, _ = next(valid)
#batch_img_test, _ = next(test)
#print(f"Batch of images shape - train: {batch_img_train.shape}, valid: {batch_img_valid.shape}, test: {batch_img_test.shape} ")
num_classes = len(train_32.class_names)
num_classes
# Out:
# Tranning image shape:
# Batch of images: (32, 300, 300, 3)
# Batch of labels: (32, 3)
#
# Validation image shape:
# Batch of images: (32, 300, 300, 3)
# Batch of labels: (32, 3)
#
# Testing image shape:
# Batch of images: (32, 300, 300, 3)
# Batch of labels: (32, 3)
#
# Images channel: 3
# 3

# %% [markdown]
# ##Model

# %% [markdown]
# #####Create model ResNet50

# %%
from keras.applications import ResNet50
from keras.models import Model
from keras.layers import Dense, Flatten

def model4():
  # Load the ResNet50 model, excluding the top dense layers
  base_resnet50 = ResNet50(weights='imagenet', include_top=False, input_shape=(height, width, img_channel))
  # Freeze the layers of the base model (optional but recommended if using pre-trained weights)
  for layer in base_resnet50.layers:
      layer.trainable = False

  # Add custom classification layers
  x = Flatten()(base_resnet50.output)
  x = Dense(128, activation='selu', kernel_initializer='lecun_normal')(x)
  predictions = Dense(3, activation='softmax')(x)

  resnet50_model = Model(inputs=base_resnet50.input, outputs=predictions)
  return resnet50_model,'resnet50'

# %% [markdown]
# #####Compile Model

# %%
def compile_model(model, optimizer):
  model.compile(    optimizer=optimizer,
                    loss='categorical_crossentropy', # para mais de duas classes e para penalizar o modelo quando há erro
                    metrics=[ #tf.keras.metrics.Accuracy(),
                              tf.keras.metrics.categorical_accuracy,
                              tf.keras.metrics.AUC(
                                                    num_thresholds = 200,
                                                    curve = 'ROC',
                                                    summation_method = 'interpolation',
                                                    name = None,
                                                    dtype = None,
                                                    thresholds = None,
                                                    multi_label = True,
                                                    num_labels = None,
                                                    label_weights = None,
                                                    from_logits = False
                                                  ),
                              tf.keras.metrics.Precision(thresholds=None, top_k=None, class_id=None, name=None, dtype=None), #Computes the precision of the predictions with respect to the labels.
                              tf.keras.metrics.Recall(thresholds=None, top_k=None, class_id=None, name=None, dtype=None),
                              tf.keras.metrics.TruePositives(thresholds=None, name=None, dtype=None),
                              tf.keras.metrics.TrueNegatives(thresholds=None, name=None, dtype=None),
                              tf.keras.metrics.FalsePositives(thresholds=None, name=None, dtype=None),
                              tf.keras.metrics.FalseNegatives(thresholds=None, name=None, dtype=None)
                            ]
                )
  return model

# %% [markdown]
# ##Train

# %% [markdown]
# #####Show end date

# %%
def calculate_total_time_min(time_start):
  time_end = time()
  time_train_seg = time_end - time_start
  time_train_min = round(time_train_seg/60, 2)
  return  time_train_min

# %% [markdown]
# #####Save History

# %%
import pickle

def save_model(model, path_dst, model_filename):
  model.save(path_dst  + model_filename)


def save_history(history, path_dst, history_filename):
  ##Save history
  with open(path_dst  + history_filename, 'wb') as f:
      pickle.dump(history.history, f)

# %% [markdown]
# #####Show Loss plot

# %%
def show_history_train(history):
  # Plot training & validation loss values
  plt.figure(figsize=(10, 6))
  plt.plot(history.history['loss'], label='Erro de treino')
  plt.plot(history.history['val_loss'], label='Erro de validação')
  #plt.title('Erro de treino e validação baseado em iterações')
  plt.xlabel('Iterações')
  plt.ylabel('Erro')
  plt.legend()
  plt.show()

# %% [markdown]
# #####Run train

# %%
from matplotlib import pyplot as plt
from time import time
from tensorflow.keras.callbacks import LearningRateScheduler, LambdaCallback


initial_learning_rate = 0.0001

def step_decay(epoch):
    initial_lrate = initial_learning_rate
    drop = 0.5
    epochs_drop = 7
    lrate = initial_lrate * (drop ** (epoch // epochs_drop))
    return lrate

def run_train(model, epochs, train, valid):
  early_stopping_patience = 10
  early_stopping = keras.callbacks.EarlyStopping(
      monitor="val_loss", patience=early_stopping_patience, restore_best_weights=True
  )
  lrate_callback = LearningRateScheduler(step_decay)
  # Create a LambdaCallback to print the learning rate at the end of each epoch
  print_lrate = LambdaCallback(on_epoch_end=lambda epoch, logs: print(f"\nLearning Rate at end of epoch {epoch}: {model.optimizer.learning_rate.numpy()}"))
  history = model.fit(
                        train,
                        #steps_per_epoch=train.n // batch_size,
                        epochs=epochs,
                        #batch_size=batch_size,
                        validation_data=valid,
                        callbacks=[early_stopping, lrate_callback, print_lrate],
                        verbose=1,
                        #validation_steps=valid.n // batch_size
                      )
  return history

def call_train(model, train, valid, epochs, batch_size, model_filename, history_filename):
  time_start = time()
  history_train = run_train(model, epochs, train, valid)
  time_train_min = calculate_total_time_min(time_start)
  print('\n')
  show_history_train(history_train)
  print('\n')
  save_model(model, dst_path, model_filename)
  save_history(history_train, dst_path, history_filename)
  return time_train_min

# %% [markdown]
# ##Test

# %% [markdown]
# #####Get Test Labels and predicitions

# %%
def get_true_and_predicted_labels(model, test_data):
  predictions = model.predict(test_data)
  predicted_labels = np.argmax(predictions, axis=1)
  #print(predictions)
  true_labels = []
  # Iterate through the test_data dataset to extract true labels
  for images, labels in test_data:
      true_labels.extend(np.argmax(labels, axis=1))
  # Convert the list of true labels to a NumPy array
  true_labels = np.array(true_labels)

  n_classes = len(np.unique(true_labels))
  return true_labels, predicted_labels, predictions, n_classes

# %% [markdown]
# #####ROC plot

# %%
from sklearn.metrics import roc_curve, auc
def plot_roc(model, test_data):
  lang = 'pt'
  if lang == 'pt':
    texts = ('Curva ROC (classe', 'Taxa de falso positivo', 'Taxa de verdadeiro positivo', 'Curvas ROC')
  else: #en
    texts = ('ROC curve (class', 'False Positive Rate', 'True Positive Rate', 'ROC Curves')


  fpr = {}
  tpr = {}
  roc_auc = {}
  true_labels, predicted_labels, predictions, n_classes = get_true_and_predicted_labels(model, test_data)
  # Compute ROC curve and ROC area for each class
  for i in range(n_classes):
      fpr[i], tpr[i], _ = roc_curve((true_labels == i).astype(int), predictions[:, i])
      roc_auc[i] = auc(fpr[i], tpr[i])

  # Plot ROC curves
  plt.figure(figsize=(8, 6))
  for i, class_name in enumerate(test_data.class_names):
    if class_name == 'health':
      new_class_name = 'saudável'
    elif class_name == 'severity1':
      new_class_name  = 'severidade1'
    elif class_name == 'severity2':
      new_class_name  = 'severidade2'
    plt.plot(fpr[i], tpr[i], lw=2, label=f'{texts[0]} {new_class_name}; AUC={roc_auc[i]:.4f})')
  #for i in range(n_classes):
  #    plt.plot(fpr[i], tpr[i], lw=2, label=f'{texts[0]} {i}) (AUC = {roc_auc[i]:.4f})')

  # Plot random chance line
  plt.plot([0, 1], [0, 1], 'k--', lw=2)

  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel(texts[1])
  plt.ylabel(texts[2])
  #plt.title(texts[3])
  plt.legend(loc='lower right')
  plt.show()

# %% [markdown]
# #####Print classes metrics

# %%
from sklearn.metrics import roc_curve, auc
def print_classes_metrics(model, test_data):
  fpr = {}
  tpr = {}
  roc_auc = {}

  true_labels, predicted_labels, predictions, n_classes = get_true_and_predicted_labels(model, test_data)
  # Compute ROC curve and ROC area for each class
  for i in range(n_classes):
      fpr[i], tpr[i], _ = roc_curve((true_labels == i).astype(int), predictions[:, i])
      roc_auc[i] = auc(fpr[i], tpr[i])
      precision[i], recall[i], _ = precision_recall_curve((true_labels == i).astype(int), predictions[:, i])
      f1_score[i] = 2 * (precision[i] * recall[i]) / (precision[i] + recall[i])

      print(f'\n\nClass {i} Metrics')

# %% [markdown]
# #####Confusion Matrix

# %%
import itertools
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix
from PIL import Image

def plot_confusion_matrix(model, test_data):
    lang = 'pt'
    if lang == 'pt':
      texts = ('Matriz de confusão','Valor real', 'Valor predito')
      #classes = (test_data.class_names[0], test_data.class_names[1], test_data.class_names[2])
      for id, name in enumerate(test_data.class_names):
        if test_data.class_names[id] == 'health':
          test_data.class_names[id] = 'saudável'
        elif test_data.class_names[id] == 'severity1':
          test_data.class_names[id] = 'severidade1'
        elif test_data.class_names[id] == 'severity2':
          test_data.class_names[id] = 'severidade2'
    else:
      texts = ('Confusion matrix','True Label', 'Predicted label')

    # Use the model to predict the values from the test_images.
    test_pred_raw = model.predict(test_data)
    test_pred = np.argmax(test_pred_raw, axis=1)

    y_test = tf.concat([y for x, y in test_data], axis=0)
    test_labels = np.argmax(y_test, axis=1)

    # Calculate the confusion matrix using sklearn.metrics
    cm = confusion_matrix(y_true=test_labels, y_pred=test_pred)

    figure = plt.figure(figsize=(8, 8))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    #plt.title(texts[0])
    plt.colorbar()
    tick_marks = np.arange(len(test_data.class_names))
    plt.xticks(tick_marks, test_data.class_names, rotation=45)
    plt.yticks(tick_marks, test_data.class_names)

    # Use white text if squares are dark; otherwise black.
    threshold = cm.max() / 2.

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "white" if cm[i, j] > threshold else "black"
        plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

    plt.tight_layout()
    plt.ylabel(texts[1])
    plt.xlabel(texts[2])
    figure

# %% [markdown]
# #####Run test

# %%
def call_test(model, test_data):
  test_metrics = model.evaluate(test_data)
  print('\n');
  plot_roc(model, test_data)
  print('\n')
  plot_confusion_matrix(model, test_data)
  print('\n')
  return test_metrics

# %% [markdown]
# ##Main

# %% [markdown]
# ###Main code

# %%
def main(model, train, valid, test, learning_rate, batch_size, optimizer_param, optimizer, epochs, layers_config_number, momentum, df_history):
  print('\n\n======================================================================\n')
  print('+++ Trainning and Validation +++',end='\n\n')
  print(f'Epochs: {1} | Optmizer: {optimizer} | Batch size = {batch_size} | Learning rate = {learning_rate} | Momentum = {momentum}|Layers configuration: {layers_config_number} \n\n')
  compile_model(model, optimizer_param)
  filename = f'epochs{epochs}_batch{batch_size}_layers{layers_config_number}_momentum{momentum}'
  model_filename = f'{optimizer}/model_{optimizer}_{filename}'
  history_filename = f'{optimizer}/history_{optimizer}_{filename}'
  time_train_min = call_train(model, train, valid, epochs, batch_size, model_filename, history_filename)
  time_train_hr = round(time_train_min/60, 2)
  time_train_min = round(time_train_min, 2)
  print(f'\nTotal time for trainning and validation: {time_train_min} (min) or {time_train_hr} (hr) \n\n')
  print('\n\n +++ Testing +++ \n')
  test_metrics = call_test(model, test)
  loss = test_metrics[0]
  accuracy = test_metrics[1]
  auc = test_metrics[2]
  precision = test_metrics[3]
  recall = test_metrics[4]
  true_positives  = test_metrics[5]
  true_negatives = test_metrics[6]
  false_positives = test_metrics[7]
  false_negatives = test_metrics[8]
  list = [epochs, optimizer, batch_size, learning_rate , momentum, layers_config_number, time_train_min, time_train_hr,  loss, accuracy, auc, precision, recall, true_positives, true_negatives, false_positives, false_negatives, model_filename, history_filename]
  #df_history.loc[len(df_history)] = list
  #save_df_history(df_history, optimizer)
  del list, epochs, optimizer, batch_size, learning_rate, layers_config_number, time_train_min, time_train_hr,  loss, accuracy, auc, precision, recall, true_positives, true_negatives, false_positives, false_negatives, model_filename, history_filename, filename

# %% [markdown]
# ###Common values

# %%
epochs = 60
dataset_batch_size_list = ((train_32, valid_32, test_32), (train_64, valid_64, test_64), (train_128, valid_128, test_128))
learning_rate_list = (0.01, 0.001, 0.0001, 0.00001)
momentum_list = (0, 0.9, 0.99)

# %% [markdown]
# ###Optimizer = 'adam'

# %% [markdown]
# ####Model Sequential

# %%
#Store history to insert to sheet
df_history_adam = pd.DataFrame(columns=['Epochs', 'Optmizer', 'Batch_size', 'Learning_rate', 'Momentum','Layers_config', 'Training_time(min)', 'Training_time(hr)' , 'Loss', 'Accuracy', 'Auc', 'Precision', 'Recall', 'True_positives', 'True_negatives', 'False_positives', 'False_negatives','Model_filename' ,'History_filename'])
def call_adam_model():
  optimizer='adam '
  model_adam_print, modelid = model4()
  print(f'\nUsed Model {modelid}:\n')
  model_adam_print.summary()
  print('\n')
  for dataset_batch_size in dataset_batch_size_list:
    #for learning_rate in learning_rate_list:
    train = dataset_batch_size[0]
    valid = dataset_batch_size[1]
    test = dataset_batch_size[2]
    batch_size = get_batch_size(train)
    model_adam, layers_config_adam = model4()
    optimizer_param = keras.optimizers.Adam(learning_rate=initial_learning_rate)
    main(model=model_adam, train=train, valid=valid, test=test, learning_rate='learning_rate', batch_size=batch_size, optimizer_param=optimizer_param, optimizer=optimizer, epochs=epochs, layers_config_number=layers_config_adam, momentum='default', df_history=df_history_adam)

    del model_adam
call_adam_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
#
# Used Model resnet50:
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 300, 300, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 306, 306, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 150, 150, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 150, 150, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 150, 150, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 152, 152, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 75, 75, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 75, 75, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 75, 75, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 75, 75, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 75, 75, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 75, 75, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 75, 75, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 75, 75, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 75, 75, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 75, 75, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 75, 75, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 75, 75, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 75, 75, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 75, 75, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 75, 75, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 75, 75, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 75, 75, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 75, 75, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 75, 75, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 75, 75, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 75, 75, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 75, 75, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 75, 75, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 75, 75, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 75, 75, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 75, 75, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 75, 75, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 75, 75, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 75, 75, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 75, 75, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 75, 75, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 75, 75, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 75, 75, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 38, 38, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 38, 38, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 38, 38, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 38, 38, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 38, 38, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 38, 38, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 38, 38, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 38, 38, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 38, 38, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 38, 38, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 38, 38, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 38, 38, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 38, 38, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 38, 38, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 38, 38, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 38, 38, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 38, 38, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 38, 38, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 38, 38, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 38, 38, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 38, 38, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 38, 38, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 38, 38, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 38, 38, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 38, 38, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 38, 38, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 38, 38, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 38, 38, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 38, 38, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 38, 38, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 38, 38, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 38, 38, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 38, 38, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 38, 38, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 38, 38, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 38, 38, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 38, 38, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 38, 38, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 38, 38, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 38, 38, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 38, 38, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 38, 38, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 19, 19, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 19, 19, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 19, 19, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 19, 19, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 19, 19, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 19, 19, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 19, 19, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 19, 19, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 19, 19, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 19, 19, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 19, 19, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 19, 19, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 19, 19, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 19, 19, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 19, 19, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 19, 19, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 19, 19, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 19, 19, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 19, 19, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 19, 19, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 19, 19, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 19, 19, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 19, 19, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 19, 19, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 19, 19, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 19, 19, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 19, 19, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 19, 19, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 19, 19, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 19, 19, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 19, 19, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 19, 19, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 19, 19, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 19, 19, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 19, 19, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 19, 19, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 19, 19, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 19, 19, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 19, 19, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 19, 19, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 19, 19, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 19, 19, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 19, 19, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 19, 19, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 19, 19, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 19, 19, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 19, 19, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 19, 19, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 19, 19, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 19, 19, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 19, 19, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 19, 19, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 19, 19, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 19, 19, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 19, 19, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 19, 19, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 19, 19, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 19, 19, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 19, 19, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 19, 19, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 19, 19, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 19, 19, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 10, 10, 512)          524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 10, 10, 512)          2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 10, 10, 512)          0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 10, 10, 512)          2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 10, 10, 512)          2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 10, 10, 512)          0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 10, 10, 2048)         2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 10, 10, 2048)         1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 10, 10, 2048)         8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 10, 10, 2048)         8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 10, 10, 2048)         0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 10, 10, 2048)         0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 10, 10, 512)          1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 10, 10, 512)          2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 10, 10, 512)          0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 10, 10, 512)          2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 10, 10, 512)          2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 10, 10, 512)          0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 10, 10, 2048)         1050624   ['conv5_block2_2_relu[0][0]']
#  D)
# ...
# Epoch 44/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0400 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 43: 1.56249996052793e-06
# 10/10 [==============================] - 9s 613ms/step - loss: 0.0400 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4437 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9485 - val_precision_2: 0.8542 - val_recall_2: 0.8200 - val_true_positives_2: 123.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 27.0000 - lr: 1.5625e-06
# Epoch 45/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0399 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 44: 1.56249996052793e-06
# 10/10 [==============================] - 9s 544ms/step - loss: 0.0399 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4433 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9485 - val_precision_2: 0.8542 - val_recall_2: 0.8200 - val_true_positives_2: 123.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 27.0000 - lr: 1.5625e-06
# Epoch 46/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0397 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 45: 1.56249996052793e-06
# 10/10 [==============================] - 7s 525ms/step - loss: 0.0397 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4431 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9485 - val_precision_2: 0.8542 - val_recall_2: 0.8200 - val_true_positives_2: 123.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 27.0000 - lr: 1.5625e-06
# Epoch 47/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0396 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 46: 1.56249996052793e-06
# 10/10 [==============================] - 7s 453ms/step - loss: 0.0396 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4434 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9486 - val_precision_2: 0.8542 - val_recall_2: 0.8200 - val_true_positives_2: 123.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 27.0000 - lr: 1.5625e-06
# Epoch 48/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0394 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 47: 1.56249996052793e-06
# 10/10 [==============================] - 8s 531ms/step - loss: 0.0394 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4435 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9485 - val_precision_2: 0.8542 - val_recall_2: 0.8200 - val_true_positives_2: 123.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 27.0000 - lr: 1.5625e-06
# Epoch 49/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0393 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 48: 1.56249996052793e-06
# 10/10 [==============================] - 7s 429ms/step - loss: 0.0393 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4433 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9485 - val_precision_2: 0.8542 - val_recall_2: 0.8200 - val_true_positives_2: 123.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 27.0000 - lr: 1.5625e-06
# Epoch 50/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0392 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 49: 7.81249980263965e-07
# 10/10 [==============================] - 8s 492ms/step - loss: 0.0392 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4432 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9486 - val_precision_2: 0.8552 - val_recall_2: 0.8267 - val_true_positives_2: 124.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 26.0000 - lr: 7.8125e-07
# Epoch 51/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0391 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 50: 7.81249980263965e-07
# 10/10 [==============================] - 8s 550ms/step - loss: 0.0391 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4430 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9486 - val_precision_2: 0.8552 - val_recall_2: 0.8267 - val_true_positives_2: 124.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 26.0000 - lr: 7.8125e-07
# Epoch 52/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0390 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 51: 7.81249980263965e-07
# 10/10 [==============================] - 10s 613ms/step - loss: 0.0390 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4430 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9486 - val_precision_2: 0.8552 - val_recall_2: 0.8267 - val_true_positives_2: 124.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 26.0000 - lr: 7.8125e-07
# Epoch 53/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0390 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 52: 7.81249980263965e-07
# 10/10 [==============================] - 8s 638ms/step - loss: 0.0390 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4429 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9486 - val_precision_2: 0.8552 - val_recall_2: 0.8267 - val_true_positives_2: 124.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 26.0000 - lr: 7.8125e-07
# Epoch 54/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0389 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 53: 7.81249980263965e-07
# 10/10 [==============================] - 7s 391ms/step - loss: 0.0389 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4428 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9479 - val_precision_2: 0.8552 - val_recall_2: 0.8267 - val_true_positives_2: 124.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 26.0000 - lr: 7.8125e-07
# Epoch 55/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0388 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 54: 7.81249980263965e-07
# 10/10 [==============================] - 8s 606ms/step - loss: 0.0388 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4428 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9485 - val_precision_2: 0.8552 - val_recall_2: 0.8267 - val_true_positives_2: 124.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 26.0000 - lr: 7.8125e-07
# Epoch 56/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0387 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 55: 7.81249980263965e-07
# 10/10 [==============================] - 9s 734ms/step - loss: 0.0387 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4426 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9480 - val_precision_2: 0.8552 - val_recall_2: 0.8267 - val_true_positives_2: 124.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 26.0000 - lr: 7.8125e-07
# Epoch 57/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0387 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 56: 3.906249901319825e-07
# 10/10 [==============================] - 10s 632ms/step - loss: 0.0387 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4425 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9481 - val_precision_2: 0.8552 - val_recall_2: 0.8267 - val_true_positives_2: 124.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 26.0000 - lr: 3.9062e-07
# Epoch 58/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0386 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 57: 3.906249901319825e-07
# 10/10 [==============================] - 8s 542ms/step - loss: 0.0386 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4425 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9480 - val_precision_2: 0.8552 - val_recall_2: 0.8267 - val_true_positives_2: 124.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 26.0000 - lr: 3.9062e-07
# Epoch 59/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0386 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 58: 3.906249901319825e-07
# 10/10 [==============================] - 9s 516ms/step - loss: 0.0386 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4425 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9480 - val_precision_2: 0.8552 - val_recall_2: 0.8267 - val_true_positives_2: 124.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 26.0000 - lr: 3.9062e-07
# Epoch 60/60
# 10/10 [==============================] - ETA: 0s - loss: 0.0386 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00
# Learning Rate at end of epoch 59: 3.906249901319825e-07
# 10/10 [==============================] - 9s 706ms/step - loss: 0.0386 - categorical_accuracy: 1.0000 - auc_2: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - true_positives_2: 1200.0000 - true_negatives_2: 2400.0000 - false_positives_2: 0.0000e+00 - false_negatives_2: 0.0000e+00 - val_loss: 0.4425 - val_categorical_accuracy: 0.8467 - val_auc_2: 0.9480 - val_precision_2: 0.8552 - val_recall_2: 0.8267 - val_true_positives_2: 124.0000 - val_true_negatives_2: 279.0000 - val_false_positives_2: 21.0000 - val_false_negatives_2: 26.0000 - lr: 3.9062e-07
# Total time for trainning and validation: 8.98 (min) or 0.15 (hr)
#
#
#
#
#  +++ Testing +++
#
# 2/2 [==============================] - 1s 78ms/step - loss: 0.4237 - categorical_accuracy: 0.8533 - auc_2: 0.9462 - precision_2: 0.8562 - recall_2: 0.8333 - true_positives_2: 125.0000 - true_negatives_2: 279.0000 - false_positives_2: 21.0000 - false_negatives_2: 25.0000
#
#
# 2/2 [==============================] - 3s 433ms/step
# 2/2 [==============================] - 2s 839ms/step
